# %% [markdown]
# ## Task: Prepare Modelling data from the formatted datasets

# %%
import pandas as pd
import numpy as np
import re
from collections import defaultdict
from statistics import mode, median
import pickle
import os

from factslab.utility import load_glove_embedding
from factslab.datastructures import ConstituencyTree, DependencyTree
from factslab.pytorch.childsumtreelstm import *
#from pytorch.rnnregression import RNNRegressionTrainer
from factslab.pytorch.rnnregression import RNNRegression

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import confusion_matrix
import itertools

##Torch
import torch
from torch.nn import MSELoss, L1Loss, SmoothL1Loss, CrossEntropyLoss

# %% [markdown]
# #### Formatted datasets location

# %%
home_dir = "/Users"

# %%
data_path = "../data/"
ud_trees = home_dir + "/sidvash/Dropbox/facts_lab/UD_data_trees/structures.tsv"
train_file_p1 = "bulk_data_temporal_duration.csv"

#Taken from github - includes doc ids and sent ids
ud_train_detailed =  home_dir +"/sidvash/Dropbox/facts_lab/veridicality_sid/UD_English/en_ewt-ud-train.conllu"
ud_dev_detailed =  home_dir +"/sidvash/Dropbox/facts_lab/veridicality_sid/UD_English/en_ewt-ud-dev.conllu"
ud_test_detailed = home_dir + "/sidvash/Dropbox/facts_lab/veridicality_sid/UD_English/en_ewt-ud-test.conllu"

# %% [markdown]
# ## Structures object

# %%
ud_trees = home_dir +"/sidvash/Dropbox/facts_lab/UD_data_trees/structures.tsv"

struct_dict = {}

with open(ud_trees, 'r') as f:
    structs_sents = [line.strip().split('\t') for line in f]

for sent_id, tree_list, sent in structs_sents:
    struct_dict[sent_id] = DependencyTree.fromstring(tree_list)
    struct_dict[sent_id].sentence = sent.split(" ")
    
print(struct_dict['en-ud-dev.conllu sent_1'].sentence)
# Out:
# ['From', 'the', 'AP', 'comes', 'this', 'story', ':']

# %% [markdown]
# ## Load Data

# %%
data_p1 = pd.read_csv(data_path + train_file_p1)

# %%
cols = ["split", "worker_id", "sent_token", "sentence_id_1", "sentence_id_2", "sentence", "pred1_text", "pred2_text",
        "pred1_token", "pred2_token", "pred1_root_token", "pred2_root_token", 
       "pred1_duration", "pred2_duration", "pred1_slider", "pred2_slider",
       "pred1_dur_conf", "pred2_dur_conf", "relation_conf", "doc_id"]

out_data = data_p1[cols]

out_data['sent_pred_id1'] = out_data['sentence_id_1'] + " " + out_data['pred1_root_token'].map(lambda x: str(x))
out_data['sent_pred_id2'] = out_data['sentence_id_2'] + " " + out_data['pred2_root_token'].map(lambda x: str(x))

#out_data.head()

# %% [markdown]
# ## Pre-Process Data

# %% [markdown]
# ### 1.1 Remove empty slider positions

# %%
print(out_data.shape)
out_data = out_data[(out_data.pred1_slider!="{}") &
                   (out_data.pred2_slider!="{}")]
print(out_data.shape)
# Out:
# (85125, 22)
# (85124, 22)

# %% [markdown]
# ### 1.2 Get the slider-values into lists

# %%
out_data['pred1_slider_lst'] = out_data['pred1_slider'].map(lambda x: [int(item) for item in x.split("-")])
out_data['pred2_slider_lst'] = out_data['pred2_slider'].map(lambda x: [int(item) for item in x.split("-")])

# %% [markdown]
# ###  1.3 Extract TIME_ML tags - Coarse and coarser

# %%
def time_ml_coarser(row, var1, var2):
    '''
    Creates time ML tags (13 relations) 
    
    from slider positions of two events 
    
    Eg: EVENT 1 "is before" EVENT2
    
    Eg: Relations: is before
    '''
    ans = ""
    
    event1 = getattr(row, var1)
    event2 = getattr(row, var2)
    
    ## For debuggging
    #event1 = var1
    #event2 = var2
    
    b1, e1 = event1
    b2, e2 = event2
    
    if (b1 == b2) and (e1 == e2):
        ans = "simultaneous"
    elif e1 < b2:
        ans = "before"
    
    elif b1 > e2:
        ans = "after"
        
    elif e1 == b2:   #meets
        ans = "ibefore"
        
    elif e2 == b1:
        ans = "iafter"
        
    elif (b1==b2) and (e1 < e2):
        ans="begins"
    
    elif (b1==b2) and (e1 > e2):
        ans="begun_by"
        
    elif (e1==e2) and (b1 > b2):
        ans="ends"
        
    elif (e1==e2) and (b1 < b2):
        ans ="end_by"
        
    elif b2 < b1 and e1 < e2:
        ans = "is_included"
        
    elif b2 > b1 and e1 > e2:
        ans = "includes"
        
    elif b1 < b2 and b2 < e1 and e1 < e2:
        ans = "before_overlaps"
    
    elif b1 > b2 and b1 < e2 and e1 > e2:
        ans = "after_overlaps"
    else:
        ans = "other"
        
    return ans

def time_ml_coarse(row, var1, var2):
    '''
    Creates coarse - time ML tags (7 relations)
    from slider positions of two events 
    
    Eg: EVENT 1 "is before" EVENT2
    
    Eg: Relations: is before
    '''
    ans = ""
    event1 = getattr(row, var1)
    event2 = getattr(row, var2)
    
    ## For debuggging
    #event1 = var1
    #event2 = var2
    
    ans = time_ml_coarser(row, var1, var2)
    
    if ans=="ibefore":
        ans = "before"
    elif ans == "iafter":
        ans = "after"
    elif (ans == "begins") or (ans == "ends"):
        ans = "is_included"
    elif (ans =="begun_by") or (ans =="end_by"):
        ans = "includes"
    
    return ans

# %%
## Time-ML check tags
# values = [[[1,4], [6,10]],
# [[6,10], [1,4]],
# [[1,6], [6,10]],
# [[6,10], [1,6]],
# [[1,6], [4,10]],
# [[4,10], [1,6]],
# [[1,4], [1,10]],
# [[1,10], [1,4]],
# [[3,8], [1,10]],
# [[1,10], [3,8]],
# [[4,10], [1,10]],
# [[1,10], [4,10]],
# [[1,10], [1,10]]]

# for item in values:
#     print(time_ml_coarser(3, item[0], item[1]))
# print("\n")
# for item in values:
#     print(time_ml_coarse(3, item[0], item[1]))

# %%
out_data['time_ml_coarse'] = out_data.apply(lambda row: time_ml_coarse(row, 
                                                             'pred1_slider_lst', 
                                                             'pred2_slider_lst'),
                                    axis=1)
out_data['time_ml_coarse'] = out_data['time_ml_coarse'].astype('category')
out_data['time_ml_code_coarse'] = out_data['time_ml_coarse'].cat.codes

print(out_data['time_ml_coarse'].cat.categories)

#out_data.head()
# Out:
# Index(['after', 'after_overlaps', 'before', 'before_overlaps', 'includes',
#        'is_included', 'simultaneous'],
#       dtype='object')

# %% [markdown]
# ### 1.4 Normalize slider Values

# %%
def normalize_sliders(row, var_s1, var_s2,
                     param="slider1"):
    '''
    Input:
    var_min_slider: name of the variable having min slider value
    var_max_slider: name of the variable having max slider value
    var_s1: name of the variable having slider1 values
    var_s1: name of the variable having slider2 values
    
    Output:
    norm_slider1: normalized slider1 values
    norm_slider2: normalized slider2 values
    '''
    b1, e1 = getattr(row, var_s1)
    b2, e2 = getattr(row, var_s2)
    
    min_val = min(b1,e1,b2,e2)
    max_val = max(b1,e1,b2,e2)
    
    if param=="slider1":
        try:
            return [round((b1-min_val)/max_val,4), round((e1-min_val)/max_val, 4)]
        except:
            return [0,0]
    else:
        try:
            return [round((b2-min_val)/max_val,4), round((e2-min_val)/max_val,4)]
        except:
            return [0,0]

# %%
out_data['norm_slider1'] = out_data.apply(lambda row: normalize_sliders(row, "pred1_slider_lst", 
                                                                        "pred2_slider_lst",
                                                                        param="slider1"), axis=1)
out_data['norm_slider2'] = out_data.apply(lambda row: normalize_sliders(row, "pred1_slider_lst", 
                                                                        "pred2_slider_lst",
                                                                        param="slider2"), axis=1)
out_data.head()
# Out:
#    split  worker_id                                         sent_token  \
# 0  train        212  en-ud-train.conllu 418_17 en-ud-train.conllu 4...
# 1  train        212  en-ud-train.conllu 9490_51 en-ud-train.conllu ...
# 2  train        212  en-ud-train.conllu 7143_8 en-ud-train.conllu 7...
# 3  train        212  en-ud-train.conllu 7786_17 en-ud-train.conllu ...
# 4  train        212  en-ud-train.conllu 5729_4 en-ud-train.conllu 5...
#
#              sentence_id_1            sentence_id_2  \
# 0   en-ud-train.conllu 418   en-ud-train.conllu 418
# 1  en-ud-train.conllu 9490  en-ud-train.conllu 9490
# 2  en-ud-train.conllu 7143  en-ud-train.conllu 7144
# 3  en-ud-train.conllu 7786  en-ud-train.conllu 7787
# 4  en-ud-train.conllu 5729  en-ud-train.conllu 5729
#
#                                             sentence pred1_text  \
# 0  Again there is no official written statement f...      think
# 1  Crowds are at their thinnest &#44; but many of...       grey
# 2  1&#44;200 - Number of public - diplomacy offic...   employed
# 3  If you &#39;re going to go through the trouble...    getting
# 4  My partners and I solicit your assistance in c...    solicit
#
#                       pred2_text pred1_token           pred2_token  \
# 0                 is intentional          17                 18_19
# 1                           dark          51                    53
# 2  be the greatest threats to...           8  11_12_13_14_15_18_19
# 3      is a good nano protein...          17           4_5_6_7_8_9
# 4                         served           4                    36
#
#          ...         relation_conf  doc_id               sent_pred_id1  \
# 0        ...                     4      10   en-ud-train.conllu 418 17
# 1        ...                     4     189  en-ud-train.conllu 9490 51
# 2        ...                     4      83   en-ud-train.conllu 7143 8
# 3        ...                     4     126  en-ud-train.conllu 7786 17
# 4        ...                     4      65   en-ud-train.conllu 5729 4
#
#                 sent_pred_id2 pred1_slider_lst pred2_slider_lst  \
# 0   en-ud-train.conllu 418 19         [35, 41]         [64, 65]
# 1  en-ud-train.conllu 9490 53          [0, 65]          [0, 65]
# 2  en-ud-train.conllu 7144 14          [0, 81]          [0, 81]
# 3   en-ud-train.conllu 7787 9         [35, 44]         [0, 100]
# 4  en-ud-train.conllu 5729 36         [36, 42]          [0, 26]
#
#    time_ml_coarse  time_ml_code_coarse   norm_slider1      norm_slider2
# 0          before                    2  [0.0, 0.0923]  [0.4462, 0.4615]
# 1    simultaneous                    6     [0.0, 1.0]        [0.0, 1.0]
# 2    simultaneous                    6     [0.0, 1.0]        [0.0, 1.0]
# 3     is_included                    5   [0.35, 0.44]        [0.0, 1.0]
# 4           after                    0  [0.8571, 1.0]      [0.0, 0.619]
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 2. Ridit Score confidence values

# %%
def ridit_score(x):
    x = x.astype(int)
    x_max, x_min = x.max(), x.min()
    counts = x.value_counts()[list(range(x_max+1))].fillna(0)
    dist = counts/counts.sum()
    cumdist = dist.cumsum()
    
    def _ridit_score(i):
        if i != x_min: 
            return cumdist[i-1] + dist[i]/2
        else:
            return dist[i]/2
        
    return x.apply(_ridit_score)

out_data['relation_conf_ridit'] = out_data.groupby('worker_id').relation_conf.transform(ridit_score)
out_data['pred1_dur_conf_ridit'] = out_data.groupby('worker_id').pred1_dur_conf.transform(ridit_score)
out_data['pred2_dur_conf_ridit'] = out_data.groupby('worker_id').pred2_dur_conf.transform(ridit_score)

# %% [markdown]
# ## 3. Store median/mean duration/confidence values for dev-test data

# %%
def extract_median_mode_mean(data, sent_token_var, 
                             sent_token, median_var,
                            param="median"):
    '''
    Extract median of corresponding var values values of a sent_id
    '''
    answers = list(data[data[sent_token_var] == sent_token][median_var].values)

    if param=="median":
        return int(median(answers))
    elif param=="mean":
        return np.mean(answers)

data_mod = out_data[out_data.split != "train"]

g = data_mod.groupby(['sent_token'])
sent_token_lst = list(g.groups.keys())

## Store median duration and other confidence values:
pred1_dur_dict = {}
pred2_dur_dict = {}
pred1_dur_conf_dict = {}
pred2_dur_conf_dict = {}

rel_conf_dict = {}

for sent_token in sent_token_lst:
    pred1_dur_dict[sent_token] = extract_median_mode_mean(data_mod, 'sent_token', 
                                                          sent_token, 'pred1_duration')
    pred2_dur_dict[sent_token] = extract_median_mode_mean(data_mod, 'sent_token', 
                                                          sent_token, 'pred2_duration')
    pred1_dur_conf_dict[sent_token] = extract_median_mode_mean(data_mod, 'sent_token', 
                                                          sent_token, 'pred1_dur_conf_ridit', param="mean")
    pred2_dur_conf_dict[sent_token] = extract_median_mode_mean(data_mod, 'sent_token', 
                                                          sent_token, 'pred2_dur_conf_ridit', param="mean")
    rel_conf_dict[sent_token] = extract_median_mode_mean(data_mod, 'sent_token', 
                                                          sent_token, 'relation_conf_ridit', param="mean")

# %%
len(pred1_dur_dict)
# Out:
# 10725

# %% [markdown]
# ## 3. Extract Timelines

# %%
device=torch.device(type="cpu")

class TimelineModel(torch.nn.Module):
    '''
     A class to extract a simple timeline model from a
     given document's predicate-pair data
    '''
    def __init__(self,
                 data = None,
                 num_preds = None,
                 optimizer_class = torch.optim.Adam,
                device=torch.device(type="cpu") ,
                **kwargs):
        super().__init__()

        self.device = device
        self.fine_loss = L1Loss().to(self.device)
        
        self.pred_tensor = torch.nn.Parameter(torch.randn(num_preds,2))
        self._optimizer_class = optimizer_class

    def forward(self, local_data, **kwargs):
        '''
        INput: dataframe with cols:
                b1, e1, b2, e2, pred1_dict_idx, pred2_dict_idx
                
        Output: 
        '''
        t_sq = self.pred_tensor**2 
        
        num_preds= t_sq.size()[0]
        anchored_tensor = torch.zeros(num_preds,2)
        
        anchored_tensor[:,0] = t_sq[:,0] - t_sq[:,0].min()
        anchored_tensor[:,1] = t_sq[:,1]
        
        #Predicted values
        b1 = anchored_tensor[local_data.pred1_dict_idx.values][:,0]
        dur1 = anchored_tensor[local_data.pred1_dict_idx.values][:,1]
        b2 = anchored_tensor[local_data.pred2_dict_idx.values][:,0]
        dur2 = anchored_tensor[local_data.pred2_dict_idx.values][:,1]
        
        return b1, dur1, b2, dur2, anchored_tensor
    
    def fit(self, local_data, epochs=100, **kwargs):
        losses = [10000]
        
        print("#### Model Parameters ####")
        for name,param in self.named_parameters():     
            if param.requires_grad:
                print(name, param.shape) 
        print("##########################") 
        parameters = [p for p in self.parameters() if p.requires_grad]
        optimizer = self._optimizer_class(parameters)
        
        #Actual values
        b1_lst = local_data.b1.values
        e1_lst = local_data.e1.values
        b2_lst = local_data.b2.values
        e2_lst = local_data.e2.values
        
        actuals = self._lsts_to_tensors(b1_lst, e1_lst, b2_lst, e2_lst,
                                        param="float")
        
        for epoch in range(epochs):
            
            preds = self.forward(local_data)
            #zero_grad
            optimizer.zero_grad()
            curr_loss = self._custom_loss(preds, actuals)
            curr_loss.backward()
            optimizer.step()
            
            if epoch==0:
                print("Epoch: {}, Initial-Loss: {}".format(epoch+1, curr_loss))
               
            ## Stop training when loss converges
            if abs(curr_loss.detach() - losses[-1]) < 0.00001:
                print("Epoch: {}, Converging-Loss: {}".format(epoch+1, curr_loss))
                break
                
            losses.append(curr_loss.detach())
                
        return self.predict(preds)
        
    def _custom_loss(self, preds, actuals):
    
        b1_pred, dur1_pred, b2_pred, dur2_pred, _ = preds
        b1_act, e1_act, b2_act, e2_act = actuals
        
        ## Normalize predicted values:
        num_pairs = b1_pred.size()[0]
        t = torch.zeros(num_pairs,4)
        t[:,0] = b1_pred
        t[:,1] = b1_pred + dur1_pred
        t[:,2] = b2_pred
        t[:,3] = b2_pred + dur2_pred
        t_min, _ = torch.min(t,dim=1)
        t_max, _ = torch.max(t,dim=1)
        t = t - t_min.view(num_pairs,1)
        t = t/t_max.view(num_pairs,1)
        
        ## Fine-grained Losses
        l1 = self.fine_loss(t[:,0]-t[:,2], b1_act-b2_act)
        l2 = self.fine_loss(t[:,1]-t[:,2], e1_act-b2_act)
        l3 = self.fine_loss(t[:,3]-t[:,0], e2_act-b1_act)
        l4 = self.fine_loss(t[:,1]-t[:,3], e1_act-e2_act)
        
        a,b,c,d=0.25,0.25,0.25, 0.25 
        total_loss1 = a*l1+ b*l2+ c*l3+ d*l4
        
        ## match exact
        #l5 = self.fine_loss(t[:,0], b1_act)
        #l6 = self.fine_loss(t[:,1], e1_act)
        #l7 = self.fine_loss(t[:,2], b2_act)
        #l8 = self.fine_loss(t[:,3], e2_act)
    
        #total_loss2 = (l5+l6+l7+l8)/4
        
        return total_loss1
        
    def _lsts_to_tensors(self, *args, param=None):
        '''
        Input: list1, list2,......

        Output: [Tensor(list1), tensor(list2),....]

        '''
        if param=="float":
            return [torch.from_numpy(np.array(arg)).float().to(self.device) for arg in args]
        else:
            return [torch.from_numpy(np.array(arg, dtype="int64")).to(self.device) for arg in args]
        
    def predict(self, preds):
        b1_pred, dur1_pred, b2_pred, dur2_pred, pred_timeline = preds
        
        ## Normalize predicted values:
        num_pairs = b1_pred.size()[0]
        t = torch.zeros(num_pairs,4)
        t[:,0] = b1_pred
        t[:,1] = b1_pred + dur1_pred
        t[:,2] = b2_pred
        t[:,3] = b2_pred + dur2_pred
        t_min, _ = torch.min(t,dim=1)
        t_max, _ = torch.max(t,dim=1)
        t = t - t_min.view(num_pairs,1)
        t = (t/t_max.view(num_pairs,1)).detach().numpy()
        

        return t[:,0],t[:,1], t[:,2], t[:,3], pred_timeline.detach().numpy()

# %%
def extract_preds(doc_id, data, split_data="train"):
    '''
    Extracts a dict of predicates for a given docid and data-split
    Key: pred_sent_id
    Value: predicate-index
    '''
    cols = ['sent_pred_id1', 'sent_pred_id2', 'norm_slider1', 'norm_slider2']
    
    local_data = data[(data.split==split_data) & (out_data.doc_id == doc_id)][cols]
    local_data['b1'] = local_data['norm_slider1'].map(lambda x: x[0])
    local_data['e1'] = local_data['norm_slider1'].map(lambda x: x[1])
    local_data['b2'] = local_data['norm_slider2'].map(lambda x: x[0])
    local_data['e2'] = local_data['norm_slider2'].map(lambda x: x[1])
    
    
    preds_arr = local_data[['sent_pred_id1', 'sent_pred_id2']].values
    uniq_preds = np.unique(preds_arr.flatten())
    
    pred_dict = {}
    idx=0
    for pred in uniq_preds:
        pred_dict[pred]=idx
        idx+=1
        
    local_data['pred1_dict_idx'] = local_data['sent_pred_id1'].map(lambda x: pred_dict[x])
    local_data['pred2_dict_idx'] = local_data['sent_pred_id2'].map(lambda x: pred_dict[x])
        
    return pred_dict, idx, local_data

# %% [markdown]
# ### Extract Timelines for train-dev-test separately

# %%
def extract_predictions(data, split_data="train"):
    '''
    Extract predicted slider values and document timelines for
    a given data
    '''
    data_mod = data[data.split==split_data]
    
    doc_ids = data_mod['doc_id'].unique()
    
    doc_timelines = {}
    
    for i,doc_id in enumerate(doc_ids):
        pred_dict, num_preds, local_data = extract_preds(doc_id, data_mod, 
                                                   split_data=split_data)
        
        ## Run Timeline Model on current docid's data
        model = TimelineModel(data = local_data,
                 num_preds = num_preds,
                device=torch.device(type="cpu"))
        
        pred_b1, pred_e1, pred_b2, pred_e2, pred_timeline  = model.fit(local_data, epochs=100000)
        doc_timelines[doc_id] = pred_timeline
        
        ## Store prediction-values into the dataset
        data_mod.loc[(data_mod.doc_id == doc_id), 
                     'predicted_b1'] = pred_b1
        
        data_mod.loc[(data_mod.doc_id == doc_id), 
                     'predicted_e1'] = pred_e1
        
        data_mod.loc[(data_mod.doc_id == doc_id), 
                     'predicted_b2'] = pred_b2
        
        data_mod.loc[(data_mod.doc_id == doc_id), 
                     'predicted_e2'] = pred_e2

        print("Documents processed: {}, Curr_docid: {}\n".format(i+1, doc_id))
        
        
    return data_mod, doc_timelines

# %% [markdown]
# ## 2.1 Train_data

# %%
train_data, train_doc_timlines = extract_predictions(out_data, split_data="train")
# Out:
# #### Model Parameters ####
# pred_tensor torch.Size([171, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5102177858352661
# Epoch: 1472, Converging-Loss: 0.20063063502311707
# Documents processed: 1, Curr_docid: 10
#
# #### Model Parameters ####
# pred_tensor torch.Size([136, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5644097924232483
# Epoch: 1420, Converging-Loss: 0.19585275650024414
# Documents processed: 2, Curr_docid: 189
#
# #### Model Parameters ####
# pred_tensor torch.Size([309, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6178700923919678
# Epoch: 1839, Converging-Loss: 0.15799157321453094
# Documents processed: 3, Curr_docid: 83
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5146307349205017
# Epoch: 1532, Converging-Loss: 0.20157302916049957
# Documents processed: 4, Curr_docid: 126
#
# #### Model Parameters ####
# pred_tensor torch.Size([66, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5996086597442627
# Epoch: 1572, Converging-Loss: 0.19261521100997925
# Documents processed: 5, Curr_docid: 65
#
# #### Model Parameters ####
# pred_tensor torch.Size([152, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5751501321792603
# Epoch: 1859, Converging-Loss: 0.20070506632328033
# Documents processed: 6, Curr_docid: 77
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5904505252838135
# Epoch: 1923, Converging-Loss: 0.24118730425834656
# Documents processed: 7, Curr_docid: 439
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5631848573684692
# Epoch: 1140, Converging-Loss: 0.17605572938919067
# Documents processed: 8, Curr_docid: 465
#
# #### Model Parameters ####
# pred_tensor torch.Size([46, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5759680271148682
# Epoch: 1437, Converging-Loss: 0.2299792319536209
# Documents processed: 9, Curr_docid: 141
#
# #### Model Parameters ####
# pred_tensor torch.Size([48, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6561773419380188
# Epoch: 1237, Converging-Loss: 0.18573953211307526
# Documents processed: 10, Curr_docid: 527
#
# #### Model Parameters ####
# pred_tensor torch.Size([122, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6181707382202148
# Epoch: 1684, Converging-Loss: 0.2102636694908142
# Documents processed: 11, Curr_docid: 7
#
# #### Model Parameters ####
# pred_tensor torch.Size([124, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5715345740318298
# Epoch: 1212, Converging-Loss: 0.20158125460147858
# Documents processed: 12, Curr_docid: 72
#
# #### Model Parameters ####
# pred_tensor torch.Size([92, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6228066682815552
# Epoch: 1723, Converging-Loss: 0.1977088302373886
# Documents processed: 13, Curr_docid: 1
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6357309818267822
# Epoch: 1848, Converging-Loss: 0.204214945435524
# Documents processed: 14, Curr_docid: 383
#
# #### Model Parameters ####
# pred_tensor torch.Size([106, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5579224824905396
# Epoch: 1485, Converging-Loss: 0.18531742691993713
# Documents processed: 15, Curr_docid: 30
#
# #### Model Parameters ####
# pred_tensor torch.Size([57, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6408360004425049
# Epoch: 1571, Converging-Loss: 0.2044406235218048
# Documents processed: 16, Curr_docid: 147
#
# #### Model Parameters ####
# pred_tensor torch.Size([57, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6604645252227783
# Epoch: 1492, Converging-Loss: 0.18754321336746216
# Documents processed: 17, Curr_docid: 531
#
# #### Model Parameters ####
# pred_tensor torch.Size([114, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5146539807319641
# Epoch: 1292, Converging-Loss: 0.18137776851654053
# Documents processed: 18, Curr_docid: 63
#
# #### Model Parameters ####
# pred_tensor torch.Size([99, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5886147022247314
# Epoch: 1735, Converging-Loss: 0.18864965438842773
# Documents processed: 19, Curr_docid: 4
#
# #### Model Parameters ####
# pred_tensor torch.Size([121, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5809886455535889
# Epoch: 1635, Converging-Loss: 0.18206128478050232
# Documents processed: 20, Curr_docid: 40
#
# #### Model Parameters ####
# pred_tensor torch.Size([649, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5759036540985107
# Epoch: 1577, Converging-Loss: 0.18927034735679626
# Documents processed: 21, Curr_docid: 15
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7128234505653381
# Epoch: 714, Converging-Loss: 0.17584148049354553
# Documents processed: 22, Curr_docid: 294
#
# #### Model Parameters ####
# pred_tensor torch.Size([92, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5843841433525085
# Epoch: 1482, Converging-Loss: 0.21673591434955597
# Documents processed: 23, Curr_docid: 180
#
# #### Model Parameters ####
# pred_tensor torch.Size([278, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.539792537689209
# Epoch: 1616, Converging-Loss: 0.22453802824020386
# Documents processed: 24, Curr_docid: 81
#
# #### Model Parameters ####
# pred_tensor torch.Size([80, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5692082047462463
# Epoch: 2084, Converging-Loss: 0.1939622312784195
# Documents processed: 25, Curr_docid: 58
#
# #### Model Parameters ####
# pred_tensor torch.Size([114, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5979089140892029
# Epoch: 1438, Converging-Loss: 0.1961774080991745
# Documents processed: 26, Curr_docid: 71
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5938074588775635
# Epoch: 1267, Converging-Loss: 0.20383790135383606
# Documents processed: 27, Curr_docid: 484
#
# #### Model Parameters ####
# pred_tensor torch.Size([122, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.597091019153595
# Epoch: 1629, Converging-Loss: 0.17869508266448975
# Documents processed: 28, Curr_docid: 26
#
# #### Model Parameters ####
# pred_tensor torch.Size([164, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5553508996963501
# Epoch: 1614, Converging-Loss: 0.16898730397224426
# Documents processed: 29, Curr_docid: 70
#
# #### Model Parameters ####
# pred_tensor torch.Size([152, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.609086275100708
# Epoch: 1942, Converging-Loss: 0.16723287105560303
# Documents processed: 30, Curr_docid: 37
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6000721454620361
# Epoch: 1012, Converging-Loss: 0.21785050630569458
# Documents processed: 31, Curr_docid: 499
#
# #### Model Parameters ####
# pred_tensor torch.Size([279, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5553322434425354
# Epoch: 1439, Converging-Loss: 0.19943484663963318
# Documents processed: 32, Curr_docid: 54
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5863924026489258
# Epoch: 1542, Converging-Loss: 0.22697463631629944
# Documents processed: 33, Curr_docid: 106
#
# #### Model Parameters ####
# pred_tensor torch.Size([37, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.571715772151947
# Epoch: 1579, Converging-Loss: 0.181780144572258
# Documents processed: 34, Curr_docid: 517
#
# #### Model Parameters ####
# pred_tensor torch.Size([37, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4581732749938965
# Epoch: 721, Converging-Loss: 0.2012186348438263
# Documents processed: 35, Curr_docid: 122
#
# #### Model Parameters ####
# pred_tensor torch.Size([168, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5666418671607971
# Epoch: 1587, Converging-Loss: 0.16143861413002014
# Documents processed: 36, Curr_docid: 45
#
# #### Model Parameters ####
# pred_tensor torch.Size([51, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5638080835342407
# Epoch: 1695, Converging-Loss: 0.20157110691070557
# Documents processed: 37, Curr_docid: 133
#
# #### Model Parameters ####
# pred_tensor torch.Size([234, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.592668354511261
# Epoch: 1658, Converging-Loss: 0.19962722063064575
# Documents processed: 38, Curr_docid: 80
#
# #### Model Parameters ####
# pred_tensor torch.Size([55, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6100953817367554
# Epoch: 1262, Converging-Loss: 0.20604924857616425
# Documents processed: 39, Curr_docid: 158
#
# #### Model Parameters ####
# pred_tensor torch.Size([206, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.560792863368988
# Epoch: 1773, Converging-Loss: 0.2067868709564209
# Documents processed: 40, Curr_docid: 43
#
# #### Model Parameters ####
# pred_tensor torch.Size([148, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5290388464927673
# Epoch: 1220, Converging-Loss: 0.1942145824432373
# Documents processed: 41, Curr_docid: 185
#
# #### Model Parameters ####
# pred_tensor torch.Size([291, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5523849725723267
# Epoch: 1352, Converging-Loss: 0.19771067798137665
# Documents processed: 42, Curr_docid: 193
#
# #### Model Parameters ####
# pred_tensor torch.Size([121, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.595247745513916
# Epoch: 1587, Converging-Loss: 0.16831658780574799
# Documents processed: 43, Curr_docid: 28
#
# #### Model Parameters ####
# pred_tensor torch.Size([222, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5899391174316406
# Epoch: 1594, Converging-Loss: 0.1834421157836914
# Documents processed: 44, Curr_docid: 55
#
# #### Model Parameters ####
# pred_tensor torch.Size([187, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5955202579498291
# Epoch: 1525, Converging-Loss: 0.2226397544145584
# Documents processed: 45, Curr_docid: 44
#
# #### Model Parameters ####
# pred_tensor torch.Size([101, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5819665789604187
# Epoch: 1288, Converging-Loss: 0.20509003102779388
# Documents processed: 46, Curr_docid: 3
#
# #### Model Parameters ####
# pred_tensor torch.Size([31, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6332378387451172
# Epoch: 1594, Converging-Loss: 0.208841934800148
# Documents processed: 47, Curr_docid: 100
#
# #### Model Parameters ####
# pred_tensor torch.Size([124, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6170493364334106
# Epoch: 1461, Converging-Loss: 0.19034290313720703
# Documents processed: 48, Curr_docid: 24
#
# #### Model Parameters ####
# pred_tensor torch.Size([38, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4828197956085205
# Epoch: 1366, Converging-Loss: 0.18675589561462402
# Documents processed: 49, Curr_docid: 118
#
# #### Model Parameters ####
# pred_tensor torch.Size([18, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6027368307113647
# Epoch: 1633, Converging-Loss: 0.22301678359508514
# Documents processed: 50, Curr_docid: 433
#
# #### Model Parameters ####
# pred_tensor torch.Size([136, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5656156539916992
# Epoch: 1813, Converging-Loss: 0.19154299795627594
# Documents processed: 51, Curr_docid: 184
#
# #### Model Parameters ####
# pred_tensor torch.Size([110, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5365433096885681
# Epoch: 1490, Converging-Loss: 0.1623060554265976
# Documents processed: 52, Curr_docid: 27
#
# #### Model Parameters ####
# pred_tensor torch.Size([184, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5849581956863403
# Epoch: 1592, Converging-Loss: 0.17454706132411957
# Documents processed: 53, Curr_docid: 75
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4750736951828003
# Epoch: 291, Converging-Loss: 0.21154965460300446
# Documents processed: 54, Curr_docid: 229
#
# #### Model Parameters ####
# pred_tensor torch.Size([29, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5520680546760559
# Epoch: 1572, Converging-Loss: 0.17946001887321472
# Documents processed: 55, Curr_docid: 516
#
# #### Model Parameters ####
# pred_tensor torch.Size([152, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6264808177947998
# Epoch: 2017, Converging-Loss: 0.1768978387117386
# Documents processed: 56, Curr_docid: 41
#
# #### Model Parameters ####
# pred_tensor torch.Size([125, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5267837643623352
# Epoch: 1367, Converging-Loss: 0.19912207126617432
# Documents processed: 57, Curr_docid: 5
#
# #### Model Parameters ####
# pred_tensor torch.Size([91, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5224657654762268
# Epoch: 1105, Converging-Loss: 0.19329839944839478
# Documents processed: 58, Curr_docid: 69
#
# #### Model Parameters ####
# pred_tensor torch.Size([147, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.538217306137085
# Epoch: 1366, Converging-Loss: 0.18840008974075317
# Documents processed: 59, Curr_docid: 190
#
# #### Model Parameters ####
# pred_tensor torch.Size([228, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.559126615524292
# Epoch: 1536, Converging-Loss: 0.18735361099243164
# Documents processed: 60, Curr_docid: 13
#
# #### Model Parameters ####
# pred_tensor torch.Size([100, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5502101182937622
# Epoch: 1512, Converging-Loss: 0.17365887761116028
# Documents processed: 61, Curr_docid: 25
#
# #### Model Parameters ####
# pred_tensor torch.Size([197, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6198009848594666
# Epoch: 2093, Converging-Loss: 0.19871091842651367
# Documents processed: 62, Curr_docid: 36
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5593740940093994
# Epoch: 1012, Converging-Loss: 0.17767861485481262
# Documents processed: 63, Curr_docid: 101
#
# #### Model Parameters ####
# pred_tensor torch.Size([29, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5659765601158142
# Epoch: 1537, Converging-Loss: 0.1569269895553589
# Documents processed: 64, Curr_docid: 508
#
# #### Model Parameters ####
# pred_tensor torch.Size([83, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6279762387275696
# Epoch: 1455, Converging-Loss: 0.20506513118743896
# Documents processed: 65, Curr_docid: 539
#
# #### Model Parameters ####
# pred_tensor torch.Size([147, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5961940884590149
# Epoch: 1771, Converging-Loss: 0.18103601038455963
# Documents processed: 66, Curr_docid: 32
#
# #### Model Parameters ####
# pred_tensor torch.Size([24, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5808351039886475
# Epoch: 1659, Converging-Loss: 0.17879171669483185
# Documents processed: 67, Curr_docid: 471
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7102575898170471
# Epoch: 1960, Converging-Loss: 0.18438895046710968
# Documents processed: 68, Curr_docid: 464
#
# #### Model Parameters ####
# pred_tensor torch.Size([257, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5542830228805542
# Epoch: 1525, Converging-Loss: 0.2115209996700287
# Documents processed: 69, Curr_docid: 78
#
# #### Model Parameters ####
# pred_tensor torch.Size([76, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6098052263259888
# Epoch: 1504, Converging-Loss: 0.21130622923374176
# Documents processed: 70, Curr_docid: 56
#
# #### Model Parameters ####
# pred_tensor torch.Size([136, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5531176328659058
# Epoch: 1656, Converging-Loss: 0.14058271050453186
# Documents processed: 71, Curr_docid: 46
#
# #### Model Parameters ####
# pred_tensor torch.Size([79, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5888105034828186
# Epoch: 1884, Converging-Loss: 0.19004566967487335
# Documents processed: 72, Curr_docid: 18
#
# #### Model Parameters ####
# pred_tensor torch.Size([179, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5955387353897095
# Epoch: 1848, Converging-Loss: 0.18366263806819916
# Documents processed: 73, Curr_docid: 188
#
# #### Model Parameters ####
# pred_tensor torch.Size([145, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6138677597045898
# Epoch: 1610, Converging-Loss: 0.1890016347169876
# Documents processed: 74, Curr_docid: 35
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5354129076004028
# Epoch: 1273, Converging-Loss: 0.1887834668159485
# Documents processed: 75, Curr_docid: 304
#
# #### Model Parameters ####
# pred_tensor torch.Size([147, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6330231428146362
# Epoch: 1621, Converging-Loss: 0.19921858608722687
# Documents processed: 76, Curr_docid: 52
#
# #### Model Parameters ####
# pred_tensor torch.Size([622, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5858017206192017
# Epoch: 1660, Converging-Loss: 0.20169003307819366
# Documents processed: 77, Curr_docid: 17
#
# #### Model Parameters ####
# pred_tensor torch.Size([87, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5547586679458618
# Epoch: 1400, Converging-Loss: 0.20218650996685028
# Documents processed: 78, Curr_docid: 19
#
# #### Model Parameters ####
# pred_tensor torch.Size([58, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5820478200912476
# Epoch: 1438, Converging-Loss: 0.20239898562431335
# Documents processed: 79, Curr_docid: 169
#
# #### Model Parameters ####
# pred_tensor torch.Size([32, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6549885869026184
# Epoch: 1567, Converging-Loss: 0.2461284101009369
# Documents processed: 80, Curr_docid: 520
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5911779999732971
# Epoch: 1350, Converging-Loss: 0.13935373723506927
# Documents processed: 81, Curr_docid: 108
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5356502532958984
# Epoch: 955, Converging-Loss: 0.1899140477180481
# Documents processed: 82, Curr_docid: 436
#
# #### Model Parameters ####
# pred_tensor torch.Size([159, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5659328699111938
# Epoch: 1637, Converging-Loss: 0.20303162932395935
# Documents processed: 83, Curr_docid: 50
#
# #### Model Parameters ####
# pred_tensor torch.Size([155, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5807936191558838
# Epoch: 1582, Converging-Loss: 0.19796819984912872
# Documents processed: 84, Curr_docid: 39
#
# #### Model Parameters ####
# pred_tensor torch.Size([150, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5621346235275269
# Epoch: 1465, Converging-Loss: 0.16911619901657104
# Documents processed: 85, Curr_docid: 191
#
# #### Model Parameters ####
# pred_tensor torch.Size([60, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5428217053413391
# Epoch: 1272, Converging-Loss: 0.18481788039207458
# Documents processed: 86, Curr_docid: 164
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5038321018218994
# Epoch: 1033, Converging-Loss: 0.1670541763305664
# Documents processed: 87, Curr_docid: 321
#
# #### Model Parameters ####
# pred_tensor torch.Size([158, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5432653427124023
# Epoch: 1484, Converging-Loss: 0.1790323257446289
# Documents processed: 88, Curr_docid: 12
#
# #### Model Parameters ####
# pred_tensor torch.Size([53, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5555562376976013
# Epoch: 1284, Converging-Loss: 0.16568529605865479
# Documents processed: 89, Curr_docid: 176
#
# #### Model Parameters ####
# pred_tensor torch.Size([165, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6119848489761353
# Epoch: 1634, Converging-Loss: 0.16411924362182617
# Documents processed: 90, Curr_docid: 33
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6156339645385742
# Epoch: 1301, Converging-Loss: 0.1909814029932022
# Documents processed: 91, Curr_docid: 503
#
# #### Model Parameters ####
# pred_tensor torch.Size([126, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5768110752105713
# Epoch: 1580, Converging-Loss: 0.2108893096446991
# Documents processed: 92, Curr_docid: 182
#
# #### Model Parameters ####
# pred_tensor torch.Size([68, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.597606897354126
# Epoch: 1759, Converging-Loss: 0.1776375025510788
# Documents processed: 93, Curr_docid: 166
#
# #### Model Parameters ####
# pred_tensor torch.Size([86, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6093857884407043
# Epoch: 1623, Converging-Loss: 0.15296167135238647
# Documents processed: 94, Curr_docid: 62
#
# #### Model Parameters ####
# pred_tensor torch.Size([157, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5923555493354797
# Epoch: 1500, Converging-Loss: 0.2150399088859558
# Documents processed: 95, Curr_docid: 74
#
# #### Model Parameters ####
# pred_tensor torch.Size([612, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5727444291114807
# Epoch: 2081, Converging-Loss: 0.17975692451000214
# Documents processed: 96, Curr_docid: 16
#
# #### Model Parameters ####
# pred_tensor torch.Size([64, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5514759421348572
# Epoch: 1447, Converging-Loss: 0.17749632894992828
# Documents processed: 97, Curr_docid: 533
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5580642223358154
# Epoch: 1002, Converging-Loss: 0.14705607295036316
# Documents processed: 98, Curr_docid: 335
#
# #### Model Parameters ####
# pred_tensor torch.Size([197, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5769853591918945
# Epoch: 1577, Converging-Loss: 0.20312052965164185
# Documents processed: 99, Curr_docid: 49
#
# #### Model Parameters ####
# pred_tensor torch.Size([254, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6063141822814941
# Epoch: 1546, Converging-Loss: 0.20441386103630066
# Documents processed: 100, Curr_docid: 192
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.633506178855896
# Epoch: 1468, Converging-Loss: 0.22168928384780884
# Documents processed: 101, Curr_docid: 86
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5170769691467285
# Epoch: 990, Converging-Loss: 0.15492871403694153
# Documents processed: 102, Curr_docid: 423
#
# #### Model Parameters ####
# pred_tensor torch.Size([245, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5882769227027893
# Epoch: 1935, Converging-Loss: 0.20658990740776062
# Documents processed: 103, Curr_docid: 14
#
# #### Model Parameters ####
# pred_tensor torch.Size([103, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6038285493850708
# Epoch: 1689, Converging-Loss: 0.17352014780044556
# Documents processed: 104, Curr_docid: 42
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6129372119903564
# Epoch: 1428, Converging-Loss: 0.22113746404647827
# Documents processed: 105, Curr_docid: 95
#
# #### Model Parameters ####
# pred_tensor torch.Size([109, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5954551100730896
# Epoch: 1365, Converging-Loss: 0.1904788315296173
# Documents processed: 106, Curr_docid: 187
#
# #### Model Parameters ####
# pred_tensor torch.Size([79, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.545374870300293
# Epoch: 1617, Converging-Loss: 0.2185564786195755
# Documents processed: 107, Curr_docid: 536
#
# #### Model Parameters ####
# pred_tensor torch.Size([63, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.592353105545044
# Epoch: 1254, Converging-Loss: 0.20920678973197937
# Documents processed: 108, Curr_docid: 168
#
# #### Model Parameters ####
# pred_tensor torch.Size([153, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5643279552459717
# Epoch: 1294, Converging-Loss: 0.18760964274406433
# Documents processed: 109, Curr_docid: 48
#
# #### Model Parameters ####
# pred_tensor torch.Size([89, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.566510021686554
# Epoch: 1559, Converging-Loss: 0.160953551530838
# Documents processed: 110, Curr_docid: 173
#
# #### Model Parameters ####
# pred_tensor torch.Size([33, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6209144592285156
# Epoch: 1146, Converging-Loss: 0.2744894027709961
# Documents processed: 111, Curr_docid: 512
#
# #### Model Parameters ####
# pred_tensor torch.Size([288, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5902268886566162
# Epoch: 1716, Converging-Loss: 0.17407956719398499
# Documents processed: 112, Curr_docid: 82
# #### Model Parameters ####
# pred_tensor torch.Size([78, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5759381055831909
# Epoch: 1572, Converging-Loss: 0.19731676578521729
# Documents processed: 113, Curr_docid: 170
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.51714026927948
# Epoch: 786, Converging-Loss: 0.14108158648014069
# Documents processed: 114, Curr_docid: 388
#
# #### Model Parameters ####
# pred_tensor torch.Size([51, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5227460265159607
# Epoch: 1244, Converging-Loss: 0.1956673413515091
# Documents processed: 115, Curr_docid: 522
#
# #### Model Parameters ####
# pred_tensor torch.Size([57, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.49498462677001953
# Epoch: 1153, Converging-Loss: 0.17081516981124878
# Documents processed: 116, Curr_docid: 529
#
# #### Model Parameters ####
# pred_tensor torch.Size([32, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5464669466018677
# Epoch: 971, Converging-Loss: 0.17403720319271088
# Documents processed: 117, Curr_docid: 507
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5083928108215332
# Epoch: 1594, Converging-Loss: 0.14121153950691223
# Documents processed: 118, Curr_docid: 345
#
# #### Model Parameters ####
# pred_tensor torch.Size([61, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5878766775131226
# Epoch: 1325, Converging-Loss: 0.17676794528961182
# Documents processed: 119, Curr_docid: 152
#
# #### Model Parameters ####
# pred_tensor torch.Size([150, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5767254829406738
# Epoch: 1429, Converging-Loss: 0.21213077008724213
# Documents processed: 120, Curr_docid: 9
#
# #### Model Parameters ####
# pred_tensor torch.Size([28, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5195684432983398
# Epoch: 1113, Converging-Loss: 0.1728438287973404
# Documents processed: 121, Curr_docid: 92
#
# #### Model Parameters ####
# pred_tensor torch.Size([44, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5874864459037781
# Epoch: 1524, Converging-Loss: 0.20787766575813293
# Documents processed: 122, Curr_docid: 518
#
# #### Model Parameters ####
# pred_tensor torch.Size([204, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5993046760559082
# Epoch: 1600, Converging-Loss: 0.19790172576904297
# Documents processed: 123, Curr_docid: 11
#
# #### Model Parameters ####
# pred_tensor torch.Size([69, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6684975624084473
# Epoch: 1519, Converging-Loss: 0.1951112449169159
# Documents processed: 124, Curr_docid: 535
#
# #### Model Parameters ####
# pred_tensor torch.Size([94, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5827214121818542
# Epoch: 1513, Converging-Loss: 0.19481931626796722
# Documents processed: 125, Curr_docid: 177
#
# #### Model Parameters ####
# pred_tensor torch.Size([184, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5729072690010071
# Epoch: 1679, Converging-Loss: 0.17908760905265808
# Documents processed: 126, Curr_docid: 51
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5473951101303101
# Epoch: 1096, Converging-Loss: 0.18852628767490387
# Documents processed: 127, Curr_docid: 431
#
# #### Model Parameters ####
# pred_tensor torch.Size([45, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.631685733795166
# Epoch: 1535, Converging-Loss: 0.19233515858650208
# Documents processed: 128, Curr_docid: 523
#
# #### Model Parameters ####
# pred_tensor torch.Size([129, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5755379796028137
# Epoch: 1601, Converging-Loss: 0.17596814036369324
# Documents processed: 129, Curr_docid: 68
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5460317730903625
# Epoch: 1325, Converging-Loss: 0.2039322555065155
# Documents processed: 130, Curr_docid: 352
#
# #### Model Parameters ####
# pred_tensor torch.Size([120, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5533387064933777
# Epoch: 1554, Converging-Loss: 0.16958603262901306
# Documents processed: 131, Curr_docid: 73
#
# #### Model Parameters ####
# pred_tensor torch.Size([32, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5745665431022644
# Epoch: 1283, Converging-Loss: 0.16961006820201874
# Documents processed: 132, Curr_docid: 474
#
# #### Model Parameters ####
# pred_tensor torch.Size([246, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5651957988739014
# Epoch: 1689, Converging-Loss: 0.19664266705513
# Documents processed: 133, Curr_docid: 53
#
# #### Model Parameters ####
# pred_tensor torch.Size([32, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5871865749359131
# Epoch: 1783, Converging-Loss: 0.14165493845939636
# Documents processed: 134, Curr_docid: 502
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6179572343826294
# Epoch: 998, Converging-Loss: 0.1953483521938324
# Documents processed: 135, Curr_docid: 447
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5145116448402405
# Epoch: 1280, Converging-Loss: 0.21540845930576324
# Documents processed: 136, Curr_docid: 257
#
# #### Model Parameters ####
# pred_tensor torch.Size([101, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.650714099407196
# Epoch: 1668, Converging-Loss: 0.21364733576774597
# Documents processed: 137, Curr_docid: 540
#
# #### Model Parameters ####
# pred_tensor torch.Size([103, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.618721067905426
# Epoch: 1574, Converging-Loss: 0.18339908123016357
# Documents processed: 138, Curr_docid: 22
#
# #### Model Parameters ####
# pred_tensor torch.Size([69, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5248364806175232
# Epoch: 1350, Converging-Loss: 0.202339768409729
# Documents processed: 139, Curr_docid: 154
#
# #### Model Parameters ####
# pred_tensor torch.Size([62, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5396996736526489
# Epoch: 1474, Converging-Loss: 0.2628544270992279
# Documents processed: 140, Curr_docid: 528
#
# #### Model Parameters ####
# pred_tensor torch.Size([118, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.579643189907074
# Epoch: 1720, Converging-Loss: 0.17008331418037415
# Documents processed: 141, Curr_docid: 31
#
# #### Model Parameters ####
# pred_tensor torch.Size([143, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5902987122535706
# Epoch: 1481, Converging-Loss: 0.1744757890701294
# Documents processed: 142, Curr_docid: 34
#
# #### Model Parameters ####
# pred_tensor torch.Size([39, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5891388058662415
# Epoch: 1378, Converging-Loss: 0.20831355452537537
# Documents processed: 143, Curr_docid: 490
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5443177819252014
# Epoch: 1562, Converging-Loss: 0.20378915965557098
# Documents processed: 144, Curr_docid: 419
#
# #### Model Parameters ####
# pred_tensor torch.Size([100, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5687659978866577
# Epoch: 1261, Converging-Loss: 0.184187114238739
# Documents processed: 145, Curr_docid: 6
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7352636456489563
# Epoch: 2201, Converging-Loss: 0.203248992562294
# Documents processed: 146, Curr_docid: 387
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6645290851593018
# Epoch: 685, Converging-Loss: 0.15107625722885132
# Documents processed: 147, Curr_docid: 312
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5778537392616272
# Epoch: 1180, Converging-Loss: 0.2125963270664215
# Documents processed: 148, Curr_docid: 318
#
# #### Model Parameters ####
# pred_tensor torch.Size([113, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6050552129745483
# Epoch: 1542, Converging-Loss: 0.20357707142829895
# Documents processed: 149, Curr_docid: 2
#
# #### Model Parameters ####
# pred_tensor torch.Size([85, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.617214024066925
# Epoch: 1936, Converging-Loss: 0.16473206877708435
# Documents processed: 150, Curr_docid: 20
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.510085940361023
# Epoch: 1439, Converging-Loss: 0.17371124029159546
# Documents processed: 151, Curr_docid: 488
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.45529448986053467
# Epoch: 863, Converging-Loss: 0.17850856482982635
# Documents processed: 152, Curr_docid: 394
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6015980839729309
# Epoch: 1382, Converging-Loss: 0.23600517213344574
# Documents processed: 153, Curr_docid: 510
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.592553973197937
# Epoch: 1346, Converging-Loss: 0.22120431065559387
# Documents processed: 154, Curr_docid: 498
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.564401388168335
# Epoch: 1409, Converging-Loss: 0.22985953092575073
# Documents processed: 155, Curr_docid: 243
#
# #### Model Parameters ####
# pred_tensor torch.Size([31, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6552608013153076
# Epoch: 1478, Converging-Loss: 0.23506039381027222
# Documents processed: 156, Curr_docid: 521
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6708728075027466
# Epoch: 1457, Converging-Loss: 0.2120603621006012
# Documents processed: 157, Curr_docid: 467
#
# #### Model Parameters ####
# pred_tensor torch.Size([54, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6238772869110107
# Epoch: 1892, Converging-Loss: 0.2029452621936798
# Documents processed: 158, Curr_docid: 532
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5414251685142517
# Epoch: 1279, Converging-Loss: 0.2023066133260727
# Documents processed: 159, Curr_docid: 405
#
# #### Model Parameters ####
# pred_tensor torch.Size([59, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.49120140075683594
# Epoch: 1126, Converging-Loss: 0.21458643674850464
# Documents processed: 160, Curr_docid: 160
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6156436204910278
# Epoch: 1712, Converging-Loss: 0.21355384588241577
# Documents processed: 161, Curr_docid: 415
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5073700547218323
# Epoch: 1161, Converging-Loss: 0.11705294251441956
# Documents processed: 162, Curr_docid: 284
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6125333309173584
# Epoch: 1531, Converging-Loss: 0.25543949007987976
# Documents processed: 163, Curr_docid: 427
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6234166622161865
# Epoch: 1168, Converging-Loss: 0.23649466037750244
# Documents processed: 164, Curr_docid: 195
#
# #### Model Parameters ####
# pred_tensor torch.Size([107, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5107381939888
# Epoch: 1844, Converging-Loss: 0.17287510633468628
# Documents processed: 165, Curr_docid: 181
#
# #### Model Parameters ####
# pred_tensor torch.Size([55, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5649412870407104
# Epoch: 1569, Converging-Loss: 0.1970820426940918
# Documents processed: 166, Curr_docid: 139
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5247766971588135
# Epoch: 1534, Converging-Loss: 0.19380120933055878
# Documents processed: 167, Curr_docid: 127
#
# #### Model Parameters ####
# pred_tensor torch.Size([227, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5753220915794373
# Epoch: 1680, Converging-Loss: 0.16251643002033234
# Documents processed: 168, Curr_docid: 79
#
# #### Model Parameters ####
# pred_tensor torch.Size([42, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5863625407218933
# Epoch: 1349, Converging-Loss: 0.2240801900625229
# Documents processed: 169, Curr_docid: 103
#
# #### Model Parameters ####
# pred_tensor torch.Size([118, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5761306881904602
# Epoch: 1936, Converging-Loss: 0.18195882439613342
# Documents processed: 170, Curr_docid: 186
#
# #### Model Parameters ####
# pred_tensor torch.Size([119, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5134809017181396
# Epoch: 1451, Converging-Loss: 0.20190292596817017
# Documents processed: 171, Curr_docid: 183
#
# #### Model Parameters ####
# pred_tensor torch.Size([38, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4935910105705261
# Epoch: 1037, Converging-Loss: 0.2373477965593338
# Documents processed: 172, Curr_docid: 109
#
# #### Model Parameters ####
# pred_tensor torch.Size([32, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4761717915534973
# Epoch: 1085, Converging-Loss: 0.16278238594532013
# Documents processed: 173, Curr_docid: 120
#
# #### Model Parameters ####
# pred_tensor torch.Size([18, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5912504196166992
# Epoch: 1151, Converging-Loss: 0.2015039324760437
# Documents processed: 174, Curr_docid: 451
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4901891350746155
# Epoch: 1232, Converging-Loss: 0.1921788901090622
# Documents processed: 175, Curr_docid: 459
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6476925015449524
# Epoch: 1162, Converging-Loss: 0.21994397044181824
# Documents processed: 176, Curr_docid: 88
#
# #### Model Parameters ####
# pred_tensor torch.Size([29, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6195482015609741
# Epoch: 1091, Converging-Loss: 0.1698085367679596
# Documents processed: 177, Curr_docid: 148
#
# #### Model Parameters ####
# pred_tensor torch.Size([63, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6314468383789062
# Epoch: 1628, Converging-Loss: 0.24047601222991943
# Documents processed: 178, Curr_docid: 525
#
# #### Model Parameters ####
# pred_tensor torch.Size([40, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5206533670425415
# Epoch: 1205, Converging-Loss: 0.23246261477470398
# Documents processed: 179, Curr_docid: 138
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6304214596748352
# Epoch: 1408, Converging-Loss: 0.1725410372018814
# Documents processed: 180, Curr_docid: 466
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.534656286239624
# Epoch: 773, Converging-Loss: 0.15093204379081726
# Documents processed: 181, Curr_docid: 369
#
# #### Model Parameters ####
# pred_tensor torch.Size([74, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5340587496757507
# Epoch: 1343, Converging-Loss: 0.21188050508499146
# Documents processed: 182, Curr_docid: 538
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5275592803955078
# Epoch: 1045, Converging-Loss: 0.18611913919448853
# Documents processed: 183, Curr_docid: 104
#
# #### Model Parameters ####
# pred_tensor torch.Size([59, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5197911262512207
# Epoch: 1620, Converging-Loss: 0.1768721491098404
# Documents processed: 184, Curr_docid: 537
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6431711912155151
# Epoch: 1349, Converging-Loss: 0.21504142880439758
# Documents processed: 185, Curr_docid: 483
#
# #### Model Parameters ####
# pred_tensor torch.Size([91, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5696128010749817
# Epoch: 1494, Converging-Loss: 0.21439851820468903
# Documents processed: 186, Curr_docid: 61
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5545980930328369
# Epoch: 1585, Converging-Loss: 0.19405759871006012
# Documents processed: 187, Curr_docid: 453
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6323316693305969
# Epoch: 537, Converging-Loss: 0.3829488158226013
# Documents processed: 188, Curr_docid: 210
#
# #### Model Parameters ####
# pred_tensor torch.Size([138, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.575684666633606
# Epoch: 1642, Converging-Loss: 0.21472367644309998
# Documents processed: 189, Curr_docid: 8
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7880498170852661
# Epoch: 1657, Converging-Loss: 0.23819130659103394
# Documents processed: 190, Curr_docid: 472
#
# #### Model Parameters ####
# pred_tensor torch.Size([59, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5654622316360474
# Epoch: 1379, Converging-Loss: 0.1876523643732071
# Documents processed: 191, Curr_docid: 151
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6021720170974731
# Epoch: 1264, Converging-Loss: 0.18068668246269226
# Documents processed: 192, Curr_docid: 475
#
# #### Model Parameters ####
# pred_tensor torch.Size([92, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5915213823318481
# Epoch: 1541, Converging-Loss: 0.16681262850761414
# Documents processed: 193, Curr_docid: 29
#
# #### Model Parameters ####
# pred_tensor torch.Size([38, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5786663889884949
# Epoch: 1319, Converging-Loss: 0.21531586349010468
# Documents processed: 194, Curr_docid: 530
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6474753618240356
# Epoch: 1135, Converging-Loss: 0.1889362335205078
# Documents processed: 195, Curr_docid: 351
#
# #### Model Parameters ####
# pred_tensor torch.Size([151, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.561454176902771
# Epoch: 1680, Converging-Loss: 0.1921394169330597
# Documents processed: 196, Curr_docid: 76
#
# #### Model Parameters ####
# pred_tensor torch.Size([29, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5470559000968933
# Epoch: 906, Converging-Loss: 0.1743660867214203
# Documents processed: 197, Curr_docid: 445
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7016881108283997
# Epoch: 991, Converging-Loss: 0.2645459771156311
# Documents processed: 198, Curr_docid: 282
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5860006809234619
# Epoch: 1517, Converging-Loss: 0.19979646801948547
# Documents processed: 199, Curr_docid: 420
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7336598634719849
# Epoch: 1497, Converging-Loss: 0.21026715636253357
# Documents processed: 200, Curr_docid: 94
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7728793621063232
# Epoch: 1897, Converging-Loss: 0.18202157318592072
# Documents processed: 201, Curr_docid: 320
#
# #### Model Parameters ####
# pred_tensor torch.Size([18, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5830309391021729
# Epoch: 1387, Converging-Loss: 0.22707325220108032
# Documents processed: 202, Curr_docid: 428
#
# #### Model Parameters ####
# pred_tensor torch.Size([47, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5669586658477783
# Epoch: 1340, Converging-Loss: 0.20446272194385529
# Documents processed: 203, Curr_docid: 150
#
# #### Model Parameters ####
# pred_tensor torch.Size([46, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5517436861991882
# Epoch: 1237, Converging-Loss: 0.22563795745372772
# Documents processed: 204, Curr_docid: 153
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5011817216873169
# Epoch: 1148, Converging-Loss: 0.20138399302959442
# Documents processed: 205, Curr_docid: 493
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5130175352096558
# Epoch: 1758, Converging-Loss: 0.16525304317474365
# Documents processed: 206, Curr_docid: 449
#
# #### Model Parameters ####
# pred_tensor torch.Size([33, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7031202912330627
# Epoch: 1176, Converging-Loss: 0.20415657758712769
# Documents processed: 207, Curr_docid: 90
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5942363739013672
# Epoch: 1000, Converging-Loss: 0.21462498605251312
# Documents processed: 208, Curr_docid: 364
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5427142977714539
# Epoch: 1381, Converging-Loss: 0.20725859701633453
# Documents processed: 209, Curr_docid: 438
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4039188623428345
# Epoch: 942, Converging-Loss: 0.20862546563148499
# Documents processed: 210, Curr_docid: 482
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5695556998252869
# Epoch: 1007, Converging-Loss: 0.2013089805841446
# Documents processed: 211, Curr_docid: 399
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6506083011627197
# Epoch: 1499, Converging-Loss: 0.19066806137561798
# Documents processed: 212, Curr_docid: 361
#
# #### Model Parameters ####
# pred_tensor torch.Size([90, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5228269100189209
# Epoch: 1481, Converging-Loss: 0.1805238574743271
# Documents processed: 213, Curr_docid: 178
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.556267261505127
# Epoch: 1904, Converging-Loss: 0.20336602628231049
# Documents processed: 214, Curr_docid: 452
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.48396581411361694
# Epoch: 1282, Converging-Loss: 0.22142791748046875
# Documents processed: 215, Curr_docid: 456
#
# #### Model Parameters ####
# pred_tensor torch.Size([71, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6121715903282166
# Epoch: 1663, Converging-Loss: 0.19545958936214447
# Documents processed: 216, Curr_docid: 174
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5679821968078613
# Epoch: 1193, Converging-Loss: 0.22049137949943542
# Documents processed: 217, Curr_docid: 441
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ...
# Epoch: 1137, Converging-Loss: 0.20057182013988495
# Documents processed: 466, Curr_docid: 196
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.41704243421554565
# Epoch: 880, Converging-Loss: 0.11905261129140854
# Documents processed: 467, Curr_docid: 314
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6111537218093872
# Epoch: 1035, Converging-Loss: 0.13990941643714905
# Documents processed: 468, Curr_docid: 231
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.45321229100227356
# Epoch: 1134, Converging-Loss: 0.19827449321746826
# Documents processed: 469, Curr_docid: 367
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6098288893699646
# Epoch: 1319, Converging-Loss: 0.13937833905220032
# Documents processed: 470, Curr_docid: 338
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5076884031295776
# Epoch: 766, Converging-Loss: 0.12852412462234497
# Documents processed: 471, Curr_docid: 281
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5883873701095581
# Epoch: 1467, Converging-Loss: 0.16714991629123688
# Documents processed: 472, Curr_docid: 260
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5313101410865784
# Epoch: 1157, Converging-Loss: 0.1826207935810089
# Documents processed: 473, Curr_docid: 119
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.37758898735046387
# Epoch: 903, Converging-Loss: 0.09149246662855148
# Documents processed: 474, Curr_docid: 253
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4086872935295105
# Epoch: 763, Converging-Loss: 0.15928739309310913
# Documents processed: 475, Curr_docid: 247
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7046530246734619
# Epoch: 1396, Converging-Loss: 0.1863928884267807
# Documents processed: 476, Curr_docid: 350
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.564899742603302
# Epoch: 1380, Converging-Loss: 0.22489750385284424
# Documents processed: 477, Curr_docid: 272
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6926961541175842
# Epoch: 1219, Converging-Loss: 0.20214277505874634
# Documents processed: 478, Curr_docid: 368
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3949466347694397
# Epoch: 561, Converging-Loss: 0.128032386302948
# Documents processed: 479, Curr_docid: 222
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.44447940587997437
# Epoch: 447, Converging-Loss: 0.2279394567012787
# Documents processed: 480, Curr_docid: 298
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7899677753448486
# Epoch: 1402, Converging-Loss: 0.2127440720796585
# Documents processed: 481, Curr_docid: 237
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6175827383995056
# Epoch: 753, Converging-Loss: 0.32917875051498413
# Documents processed: 482, Curr_docid: 287
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6065542697906494
# Epoch: 968, Converging-Loss: 0.11898558586835861
# Documents processed: 483, Curr_docid: 363
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7186669111251831
# Epoch: 1009, Converging-Loss: 0.171117901802063
# Documents processed: 484, Curr_docid: 252
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5228692293167114
# Epoch: 1487, Converging-Loss: 0.23281364142894745
# Documents processed: 485, Curr_docid: 256
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6906894445419312
# Epoch: 1606, Converging-Loss: 0.18815071880817413
# Documents processed: 486, Curr_docid: 300
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6908633708953857
# Epoch: 1437, Converging-Loss: 0.13565300405025482
# Documents processed: 487, Curr_docid: 204
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6453616619110107
# Epoch: 847, Converging-Loss: 0.24790479242801666
# Documents processed: 488, Curr_docid: 212
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5375292301177979
# Epoch: 154, Converging-Loss: 0.4257120192050934
# Documents processed: 489, Curr_docid: 248
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.8214742541313171
# Epoch: 1016, Converging-Loss: 0.1652735471725464
# Documents processed: 490, Curr_docid: 217
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4764544367790222
# Epoch: 1153, Converging-Loss: 0.169781893491745
# Documents processed: 491, Curr_docid: 460
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4788913130760193
# Epoch: 1593, Converging-Loss: 0.13170044124126434
# Documents processed: 492, Curr_docid: 255
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7092185020446777
# Epoch: 1309, Converging-Loss: 0.2261507362127304
# Documents processed: 493, Curr_docid: 220
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.472755491733551
# Epoch: 1509, Converging-Loss: 0.14470668137073517
# Documents processed: 494, Curr_docid: 317
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6962852478027344
# Epoch: 1124, Converging-Loss: 0.1131315529346466
# Documents processed: 495, Curr_docid: 402
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5935664772987366
# Epoch: 1622, Converging-Loss: 0.18022090196609497
# Documents processed: 496, Curr_docid: 113
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6461672186851501
# Epoch: 308, Converging-Loss: 0.34110042452812195
# Documents processed: 497, Curr_docid: 266
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3721041679382324
# Epoch: 962, Converging-Loss: 0.1251644790172577
# Documents processed: 498, Curr_docid: 259
#
# #### Model Parameters ####
# pred_tensor torch.Size([4, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6649662256240845
# Epoch: 988, Converging-Loss: 0.1691664457321167
# Documents processed: 499, Curr_docid: 258
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6458982229232788
# Epoch: 1166, Converging-Loss: 0.2673555910587311
# Documents processed: 500, Curr_docid: 360
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5730515718460083
# Epoch: 1470, Converging-Loss: 0.1319531500339508
# Documents processed: 501, Curr_docid: 261
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6219067573547363
# Epoch: 2072, Converging-Loss: 0.12467390298843384
# Documents processed: 502, Curr_docid: 373
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7562831044197083
# Epoch: 1818, Converging-Loss: 0.11861157417297363
# Documents processed: 503, Curr_docid: 344
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.8291220664978027
# Epoch: 1768, Converging-Loss: 0.11742202192544937
# Documents processed: 504, Curr_docid: 249
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5275086760520935
# Epoch: 1244, Converging-Loss: 0.13688986003398895
# Documents processed: 505, Curr_docid: 262
#
# #### Model Parameters ####
# pred_tensor torch.Size([4, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6858595609664917
# Epoch: 308, Converging-Loss: 0.4730750024318695
# Documents processed: 506, Curr_docid: 288
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7132476568222046
# Epoch: 1490, Converging-Loss: 0.2093745768070221
# Documents processed: 507, Curr_docid: 263
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5591825842857361
# Epoch: 1081, Converging-Loss: 0.18650409579277039
# Documents processed: 531, Curr_docid: 270
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6008274555206299
# Epoch: 1543, Converging-Loss: 0.2314406931400299
# Documents processed: 532, Curr_docid: 209
#
# #### Model Parameters ####
# pred_tensor torch.Size([4, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7374258041381836
# Epoch: 612, Converging-Loss: 0.1097644716501236
# Documents processed: 533, Curr_docid: 224
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.47003933787345886
# Epoch: 666, Converging-Loss: 0.17776522040367126
# Documents processed: 534, Curr_docid: 236
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4376348555088043
# Epoch: 837, Converging-Loss: 0.09618531167507172
# Documents processed: 535, Curr_docid: 265
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6174796223640442
# Epoch: 688, Converging-Loss: 0.08691734820604324
# Documents processed: 536, Curr_docid: 379
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7120914459228516
# Epoch: 1599, Converging-Loss: 0.11161672323942184
# Documents processed: 537, Curr_docid: 235
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6264646649360657
# Epoch: 179, Converging-Loss: 0.4466499984264374
# Documents processed: 538, Curr_docid: 377

# %%
train_data['predicted_slider1'] = train_data.apply(lambda row: [round(row.predicted_b1,4) , 
                                                                round(row.predicted_e1,4)], axis=1)
train_data['predicted_slider2'] = train_data.apply(lambda row: [round(row.predicted_b2,4), 
                                                                round(row.predicted_e2,4)], axis=1)
train_data['predicted_timeml'] = train_data.apply(lambda row: time_ml_coarse(row, 
                                                             'predicted_slider1', 
                                                             'predicted_slider2'),
                                                                    axis=1)
train_data.drop(['predicted_b1','predicted_e1', 'predicted_b2',  'predicted_e2'],axis=1, inplace=True)
train_data.head()
# Out:
#    split  worker_id                                         sent_token  \
# 0  train        212  en-ud-train.conllu 418_17 en-ud-train.conllu 4...
# 1  train        212  en-ud-train.conllu 9490_51 en-ud-train.conllu ...
# 2  train        212  en-ud-train.conllu 7143_8 en-ud-train.conllu 7...
# 3  train        212  en-ud-train.conllu 7786_17 en-ud-train.conllu ...
# 4  train        212  en-ud-train.conllu 5729_4 en-ud-train.conllu 5...
#
#              sentence_id_1            sentence_id_2  \
# 0   en-ud-train.conllu 418   en-ud-train.conllu 418
# 1  en-ud-train.conllu 9490  en-ud-train.conllu 9490
# 2  en-ud-train.conllu 7143  en-ud-train.conllu 7144
# 3  en-ud-train.conllu 7786  en-ud-train.conllu 7787
# 4  en-ud-train.conllu 5729  en-ud-train.conllu 5729
#
#                                             sentence pred1_text  \
# 0  Again there is no official written statement f...      think
# 1  Crowds are at their thinnest &#44; but many of...       grey
# 2  1&#44;200 - Number of public - diplomacy offic...   employed
# 3  If you &#39;re going to go through the trouble...    getting
# 4  My partners and I solicit your assistance in c...    solicit
#
#                       pred2_text pred1_token           pred2_token  \
# 0                 is intentional          17                 18_19
# 1                           dark          51                    53
# 2  be the greatest threats to...           8  11_12_13_14_15_18_19
# 3      is a good nano protein...          17           4_5_6_7_8_9
# 4                         served           4                    36
#
#          ...         time_ml_coarse  time_ml_code_coarse   norm_slider1  \
# 0        ...                 before                    2  [0.0, 0.0923]
# 1        ...           simultaneous                    6     [0.0, 1.0]
# 2        ...           simultaneous                    6     [0.0, 1.0]
# 3        ...            is_included                    5   [0.35, 0.44]
# 4        ...                  after                    0  [0.8571, 1.0]
#
#        norm_slider2 relation_conf_ridit pred1_dur_conf_ridit  \
# 0  [0.4462, 0.4615]            0.583832             0.576647
# 1        [0.0, 1.0]            0.583832             0.576647
# 2        [0.0, 1.0]            0.583832             0.576647
# 3        [0.0, 1.0]            0.583832             0.576647
# 4      [0.0, 0.619]            0.583832             0.576647
#
#    pred2_dur_conf_ridit  predicted_slider1  predicted_slider2  \
# 0              0.623353      [0.0, 0.1538]   [0.0278, 0.2112]
# 1              0.623353   [0.0038, 0.7372]      [0.0, 0.7299]
# 2              0.623353   [0.0451, 0.7936]      [0.0, 0.7939]
# 3              0.623353   [0.1513, 0.4399]      [0.0, 0.8015]
# 4              0.623353    [0.639, 0.8757]      [0.0, 0.5104]
#
#    predicted_timeml
# 0   before_overlaps
# 1    after_overlaps
# 2       is_included
# 3       is_included
# 4             after
#
# [5 rows x 34 columns]

# %%
train_data.to_pickle(data_path + "pre_processed/train_preprocessed.pkl")
#train_doc_timlines.to_pickle(data_path + "pre_processed/train_timelines.pkl")

# %%
def save_obj(obj, name ):
    with open(data_path + name + '.pkl', 'wb+') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(data_path + name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
save_obj(train_doc_timlines, "pre_processed/train_timelines.pkl")

# %% [markdown]
# ## 2.2 Dev Data

# %%
dev_data, dev_doc_timlines = extract_predictions(out_data, split_data="dev")
# Out:
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5756314992904663
# Epoch: 1648, Converging-Loss: 0.27608388662338257
# Documents processed: 1, Curr_docid: 6
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5174899101257324
# Epoch: 1220, Converging-Loss: 0.2523316442966461
# Documents processed: 2, Curr_docid: 100
#
# #### Model Parameters ####
# pred_tensor torch.Size([95, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5776270627975464
# Epoch: 1432, Converging-Loss: 0.2743568420410156
# Documents processed: 3, Curr_docid: 14
#
# #### Model Parameters ####
# pred_tensor torch.Size([35, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5611345767974854
# Epoch: 1162, Converging-Loss: 0.26278847455978394
# Documents processed: 4, Curr_docid: 7
#
# #### Model Parameters ####
# pred_tensor torch.Size([41, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5523543953895569
# Epoch: 1411, Converging-Loss: 0.2583661675453186
# Documents processed: 5, Curr_docid: 64
#
# #### Model Parameters ####
# pred_tensor torch.Size([73, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5210654139518738
# Epoch: 1115, Converging-Loss: 0.24504931271076202
# Documents processed: 6, Curr_docid: 25
#
# #### Model Parameters ####
# pred_tensor torch.Size([76, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5827858448028564
# Epoch: 1327, Converging-Loss: 0.2517745792865753
# Documents processed: 7, Curr_docid: 26
#
# #### Model Parameters ####
# pred_tensor torch.Size([58, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6152487397193909
# Epoch: 1406, Converging-Loss: 0.290631502866745
# Documents processed: 8, Curr_docid: 11
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4532962143421173
# Epoch: 779, Converging-Loss: 0.22514307498931885
# Documents processed: 9, Curr_docid: 280
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6335302591323853
# Epoch: 1268, Converging-Loss: 0.2588839530944824
# Documents processed: 10, Curr_docid: 57
#
# #### Model Parameters ####
# pred_tensor torch.Size([42, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.564565896987915
# Epoch: 1415, Converging-Loss: 0.25908714532852173
# Documents processed: 11, Curr_docid: 63
#
# #### Model Parameters ####
# pred_tensor torch.Size([92, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6247766017913818
# Epoch: 1446, Converging-Loss: 0.2453938126564026
# Documents processed: 12, Curr_docid: 13
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 1.0715855360031128
# Epoch: 652, Converging-Loss: 0.2927500009536743
# Documents processed: 13, Curr_docid: 247
#
# #### Model Parameters ####
# pred_tensor torch.Size([78, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5996589660644531
# Epoch: 1516, Converging-Loss: 0.24702602624893188
# Documents processed: 14, Curr_docid: 28
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6298338770866394
# Epoch: 1908, Converging-Loss: 0.2274881899356842
# Documents processed: 15, Curr_docid: 62
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6258516311645508
# Epoch: 1467, Converging-Loss: 0.22464707493782043
# Documents processed: 16, Curr_docid: 19
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6184188723564148
# Epoch: 1743, Converging-Loss: 0.2643379271030426
# Documents processed: 17, Curr_docid: 121
#
# #### Model Parameters ####
# pred_tensor torch.Size([28, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6560230255126953
# Epoch: 1432, Converging-Loss: 0.256843239068985
# Documents processed: 18, Curr_docid: 124
#
# #### Model Parameters ####
# pred_tensor torch.Size([52, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5996701717376709
# Epoch: 1249, Converging-Loss: 0.2656855881214142
# Documents processed: 19, Curr_docid: 23
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5995033979415894
# Epoch: 1290, Converging-Loss: 0.28685110807418823
# Documents processed: 20, Curr_docid: 61
#
# #### Model Parameters ####
# pred_tensor torch.Size([98, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5586477518081665
# Epoch: 2031, Converging-Loss: 0.2517618238925934
# Documents processed: 21, Curr_docid: 29
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6800749897956848
# Epoch: 1002, Converging-Loss: 0.2227376401424408
# Documents processed: 22, Curr_docid: 51
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6678335070610046
# Epoch: 1492, Converging-Loss: 0.2271275669336319
# Documents processed: 23, Curr_docid: 40
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5142016410827637
# Epoch: 1347, Converging-Loss: 0.23904259502887726
# Documents processed: 24, Curr_docid: 20
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5175092220306396
# Epoch: 1070, Converging-Loss: 0.25804272294044495
# Documents processed: 25, Curr_docid: 306
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6675095558166504
# Epoch: 1389, Converging-Loss: 0.27204975485801697
# Documents processed: 26, Curr_docid: 15
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5679911375045776
# Epoch: 1621, Converging-Loss: 0.2882733941078186
# Documents processed: 27, Curr_docid: 16
#
# #### Model Parameters ####
# pred_tensor torch.Size([47, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5336794853210449
# Epoch: 1528, Converging-Loss: 0.27385371923446655
# Documents processed: 28, Curr_docid: 22
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6037526726722717
# Epoch: 530, Converging-Loss: 0.2196539342403412
# Documents processed: 29, Curr_docid: 293
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6259202361106873
# Epoch: 1061, Converging-Loss: 0.22878313064575195
# Documents processed: 30, Curr_docid: 261
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6062427163124084
# Epoch: 1721, Converging-Loss: 0.27241092920303345
# Documents processed: 31, Curr_docid: 17
#
# #### Model Parameters ####
# pred_tensor torch.Size([28, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5696927905082703
# Epoch: 1138, Converging-Loss: 0.2754833698272705
# Documents processed: 32, Curr_docid: 125
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6369132995605469
# Epoch: 1317, Converging-Loss: 0.2573520541191101
# Documents processed: 33, Curr_docid: 59
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6776269674301147
# Epoch: 1097, Converging-Loss: 0.2800780236721039
# Documents processed: 34, Curr_docid: 122
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5294232964515686
# Epoch: 842, Converging-Loss: 0.25673946738243103
# Documents processed: 35, Curr_docid: 54
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5839331150054932
# Epoch: 1329, Converging-Loss: 0.2816692590713501
# Documents processed: 36, Curr_docid: 58
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5740564465522766
# Epoch: 1627, Converging-Loss: 0.23029963672161102
# Documents processed: 37, Curr_docid: 126
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6184614896774292
# Epoch: 1107, Converging-Loss: 0.25383177399635315
# Documents processed: 38, Curr_docid: 95
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5845240950584412
# Epoch: 1002, Converging-Loss: 0.30492261052131653
# Documents processed: 39, Curr_docid: 39
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5244674682617188
# Epoch: 1012, Converging-Loss: 0.2766019105911255
# Documents processed: 40, Curr_docid: 113
#
# #### Model Parameters ####
# pred_tensor torch.Size([18, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5910168290138245
# Epoch: 1411, Converging-Loss: 0.2650994062423706
# Documents processed: 41, Curr_docid: 50
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.741685152053833
# Epoch: 969, Converging-Loss: 0.32005906105041504
# Documents processed: 42, Curr_docid: 83
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.46178704500198364
# Epoch: 867, Converging-Loss: 0.2910256087779999
# Documents processed: 43, Curr_docid: 267
#
# #### Model Parameters ####
# pred_tensor torch.Size([81, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5617026686668396
# Epoch: 1259, Converging-Loss: 0.2673793435096741
# Documents processed: 44, Curr_docid: 12
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5390913486480713
# Epoch: 1308, Converging-Loss: 0.27420318126678467
# Documents processed: 45, Curr_docid: 112
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3235321640968323
# Epoch: 567, Converging-Loss: 0.19628798961639404
# Documents processed: 46, Curr_docid: 272
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5635017156600952
# Epoch: 1143, Converging-Loss: 0.2715098261833191
# Documents processed: 47, Curr_docid: 91
#
# #### Model Parameters ####
# pred_tensor torch.Size([53, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5320191979408264
# Epoch: 1455, Converging-Loss: 0.24946476519107819
# Documents processed: 48, Curr_docid: 10
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6716341376304626
# Epoch: 1175, Converging-Loss: 0.29172423481941223
# Documents processed: 49, Curr_docid: 304
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6451187133789062
# Epoch: 1080, Converging-Loss: 0.25668612122535706
# Documents processed: 50, Curr_docid: 79
#
# #### Model Parameters ####
# pred_tensor torch.Size([39, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5479884743690491
# Epoch: 1265, Converging-Loss: 0.2158394306898117
# Documents processed: 51, Curr_docid: 24
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6073288917541504
# Epoch: 1404, Converging-Loss: 0.26363950967788696
# Documents processed: 52, Curr_docid: 18
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6691910624504089
# Epoch: 1411, Converging-Loss: 0.25656935572624207
# Documents processed: 53, Curr_docid: 104
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6790099143981934
# Epoch: 891, Converging-Loss: 0.3328183889389038
# Documents processed: 54, Curr_docid: 96
#
# #### Model Parameters ####
# pred_tensor torch.Size([4, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.42226535081863403
# Epoch: 577, Converging-Loss: 0.2109379917383194
# Documents processed: 55, Curr_docid: 278
#
# #### Model Parameters ####
# pred_tensor torch.Size([50, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5862696766853333
# Epoch: 1425, Converging-Loss: 0.27864593267440796
# Documents processed: 56, Curr_docid: 65
#
# #### Model Parameters ####
# pred_tensor torch.Size([62, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5527733564376831
# Epoch: 1320, Converging-Loss: 0.24016806483268738
# Documents processed: 57, Curr_docid: 27
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6271016597747803
# Epoch: 1203, Converging-Loss: 0.29645949602127075
# Documents processed: 58, Curr_docid: 118
#
# #### Model Parameters ####
# pred_tensor torch.Size([9, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6304408311843872
# Epoch: 1416, Converging-Loss: 0.24544844031333923
# Documents processed: 59, Curr_docid: 43
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6270632743835449
# Epoch: 1596, Converging-Loss: 0.2689029276371002
# Documents processed: 60, Curr_docid: 98
#
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6115841865539551
# Epoch: 2084, Converging-Loss: 0.2429540455341339
# Documents processed: 61, Curr_docid: 107
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.575133204460144
# Epoch: 1508, Converging-Loss: 0.2538292407989502
# Documents processed: 62, Curr_docid: 60
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5807805061340332
# Epoch: 1680, Converging-Loss: 0.21966421604156494
# Documents processed: 63, Curr_docid: 21
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5177810192108154
# Epoch: 884, Converging-Loss: 0.2678474187850952
# Documents processed: 64, Curr_docid: 46
#
# #### Model Parameters ####
# pred_tensor torch.Size([23, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6515059471130371
# Epoch: 1682, Converging-Loss: 0.26803335547447205
# Documents processed: 65, Curr_docid: 55
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4992051124572754
# Epoch: 1056, Converging-Loss: 0.2633594870567322
# Documents processed: 66, Curr_docid: 4
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7109820246696472
# Epoch: 1383, Converging-Loss: 0.2768406569957733
# Documents processed: 67, Curr_docid: 89
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6063708066940308
# Epoch: 2008, Converging-Loss: 0.2549910247325897
# Documents processed: 68, Curr_docid: 110
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4844593405723572
# Epoch: 768, Converging-Loss: 0.23480993509292603
# Documents processed: 69, Curr_docid: 282
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5925233364105225
# Epoch: 913, Converging-Loss: 0.17313630878925323
# Documents processed: 70, Curr_docid: 298
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7577452063560486
# Epoch: 1387, Converging-Loss: 0.22852464020252228
# Documents processed: 71, Curr_docid: 270
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6758773326873779
# Epoch: 1347, Converging-Loss: 0.2934485673904419
# Documents processed: 72, Curr_docid: 44
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5750237703323364
# Epoch: 1565, Converging-Loss: 0.261949360370636
# Documents processed: 73, Curr_docid: 115
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6205611228942871
# Epoch: 1644, Converging-Loss: 0.2413243055343628
# Documents processed: 74, Curr_docid: 105
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5173315405845642
# Epoch: 1254, Converging-Loss: 0.27240505814552307
# Documents processed: 75, Curr_docid: 123
# #### Model Parameters ####
# pred_tensor torch.Size([14, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.562077522277832
# Epoch: 764, Converging-Loss: 0.30948299169540405
# Documents processed: 76, Curr_docid: 116
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7594197392463684
# Epoch: 1024, Converging-Loss: 0.26752158999443054
# Documents processed: 77, Curr_docid: 232
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6664911508560181
# Epoch: 1072, Converging-Loss: 0.25715795159339905
# Documents processed: 78, Curr_docid: 316
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6284805536270142
# Epoch: 1538, Converging-Loss: 0.2460421621799469
# Documents processed: 79, Curr_docid: 82
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6653388738632202
# Epoch: 1375, Converging-Loss: 0.2427486926317215
# Documents processed: 80, Curr_docid: 307
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.688084602355957
# Epoch: 990, Converging-Loss: 0.2825550138950348
# Documents processed: 81, Curr_docid: 111
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5971736907958984
# Epoch: 1649, Converging-Loss: 0.2374047338962555
# Documents processed: 82, Curr_docid: 103
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.863239049911499
# Epoch: 1713, Converging-Loss: 0.2743033766746521
# Documents processed: 83, Curr_docid: 266
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.590804934501648
# Epoch: 1155, Converging-Loss: 0.2475590705871582
# Documents processed: 84, Curr_docid: 93
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.627916693687439
# Epoch: 1254, Converging-Loss: 0.24387085437774658
# Documents processed: 85, Curr_docid: 119
#
# #### Model Parameters ####
# pred_tensor torch.Size([7, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5527843832969666
# Epoch: 740, Converging-Loss: 0.27399513125419617
# Documents processed: 86, Curr_docid: 301
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5420330762863159
# Epoch: 1716, Converging-Loss: 0.23337465524673462
# Documents processed: 87, Curr_docid: 5
#
# #### Model Parameters ####
# pred_tensor torch.Size([41, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6243816614151001
# Epoch: 1177, Converging-Loss: 0.2711435854434967
# Documents processed: 88, Curr_docid: 8
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4747299551963806
# Epoch: 815, Converging-Loss: 0.3185202479362488
# Documents processed: 89, Curr_docid: 75
#
# #### Model Parameters ####
# pred_tensor torch.Size([5, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.8711270689964294
# Epoch: 1045, Converging-Loss: 0.3060246407985687
# Documents processed: 90, Curr_docid: 30
#
# #### Model Parameters ####
# pred_tensor torch.Size([11, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6481611132621765
# Epoch: 985, Converging-Loss: 0.24467399716377258
# Documents processed: 91, Curr_docid: 45
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6592211723327637
# Epoch: 468, Converging-Loss: 0.2188943773508072
# Documents processed: 222, Curr_docid: 182
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3371245563030243
# Epoch: 363, Converging-Loss: 0.24295000731945038
# Documents processed: 223, Curr_docid: 186
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.416070818901062
# Epoch: 763, Converging-Loss: 0.1899166703224182
# Documents processed: 224, Curr_docid: 66
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7890956997871399
# Epoch: 350, Converging-Loss: 0.42278337478637695
# Documents processed: 225, Curr_docid: 246
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.2579059600830078
# Epoch: 260, Converging-Loss: 0.1758735328912735
# Documents processed: 226, Curr_docid: 228
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.9639889001846313
# Epoch: 520, Converging-Loss: 0.2589166462421417
# Documents processed: 227, Curr_docid: 239
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7397079467773438
# Epoch: 581, Converging-Loss: 0.1805500090122223
# Documents processed: 228, Curr_docid: 253
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5963173508644104
# Epoch: 854, Converging-Loss: 0.21024999022483826
# Documents processed: 229, Curr_docid: 284
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7228882312774658
# Epoch: 663, Converging-Loss: 0.25263333320617676
# Documents processed: 230, Curr_docid: 245
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5158072113990784
# Epoch: 221, Converging-Loss: 0.38286665081977844
# Documents processed: 231, Curr_docid: 76
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.773934006690979
# Epoch: 458, Converging-Loss: 0.34958335757255554
# Documents processed: 232, Curr_docid: 166

# %%
dev_data['predicted_slider1'] = dev_data.apply(lambda row: [round(row.predicted_b1,4) , 
                                                                round(row.predicted_e1,4)], axis=1)
dev_data['predicted_slider2'] = dev_data.apply(lambda row: [round(row.predicted_b2,4), 
                                                                round(row.predicted_e2,4)], axis=1)
dev_data['predicted_timeml_coarse'] = dev_data.apply(lambda row: time_ml_coarse(row, 
                                                             'predicted_slider1', 
                                                             'predicted_slider2'),
                                                                    axis=1)
dev_data.drop(['predicted_b1','predicted_e1', 'predicted_b2',  'predicted_e2'],axis=1, inplace=True)
#dev_data.head()
print(dev_data.shape)
# Out:
# (16304, 34)

# %%
## Restore only the top row by sent_token:
dev_data = dev_data.groupby(['sent_token']).first().reset_index()
print(dev_data.shape)
    
## Replace duration and confidence values with median/mean values
dev_data['pred1_duration'] = dev_data.apply(lambda row: pred1_dur_dict[row.sent_token], axis=1)
dev_data['pred2_duration'] = dev_data.apply(lambda row: pred2_dur_dict[row.sent_token], axis=1)
dev_data['pred1_dur_conf_ridit'] = dev_data.apply(lambda row: pred1_dur_conf_dict[row.sent_token], axis=1)
dev_data['pred2_dur_conf_ridit'] = dev_data.apply(lambda row: pred2_dur_conf_dict[row.sent_token], axis=1)
dev_data['relation_conf_ridit'] = dev_data.apply(lambda row: rel_conf_dict[row.sent_token], axis=1)

## Drop variables that don't make sense:
cols_drop = ['worker_id', 'pred1_slider', 'pred2_slider', 
             'pred1_slider_lst', 'pred2_slider_lst',
            'time_ml_coarse', 'time_ml_code_coarse', 
            'norm_slider1', 'norm_slider2']

dev_data = dev_data.drop(cols_drop, axis=1)
# Out:
# (5613, 34)

# %%
dev_data.to_pickle(data_path + "pre_processed/dev_preprocessed.pkl")
save_obj(dev_doc_timlines, "pre_processed/dev_timelines.pkl")

# %% [markdown]
# ## 2.3 Test Data

# %%
test_data, test_doc_timlines = extract_predictions(out_data, split_data="test")
# Out:
# #### Model Parameters ####
# pred_tensor torch.Size([54, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.551242470741272
# Epoch: 1641, Converging-Loss: 0.2531256079673767
# Documents processed: 1, Curr_docid: 9
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6102219820022583
# Epoch: 990, Converging-Loss: 0.28004923462867737
# Documents processed: 2, Curr_docid: 299
#
# #### Model Parameters ####
# pred_tensor torch.Size([83, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5605191588401794
# Epoch: 1265, Converging-Loss: 0.26492512226104736
# Documents processed: 3, Curr_docid: 37
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6676499843597412
# Epoch: 1235, Converging-Loss: 0.22958961129188538
# Documents processed: 4, Curr_docid: 108
#
# #### Model Parameters ####
# pred_tensor torch.Size([40, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5803752541542053
# Epoch: 1327, Converging-Loss: 0.25155922770500183
# Documents processed: 5, Curr_docid: 29
#
# #### Model Parameters ####
# pred_tensor torch.Size([33, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5660668611526489
# Epoch: 1798, Converging-Loss: 0.2766180634498596
# Documents processed: 6, Curr_docid: 59
#
# #### Model Parameters ####
# pred_tensor torch.Size([31, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6084522604942322
# Epoch: 1022, Converging-Loss: 0.27221953868865967
# Documents processed: 7, Curr_docid: 131
#
# #### Model Parameters ####
# pred_tensor torch.Size([36, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5804601907730103
# Epoch: 1389, Converging-Loss: 0.2798638939857483
# Documents processed: 8, Curr_docid: 62
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.23316176235675812
# Epoch: 374, Converging-Loss: 0.11272000521421432
# Documents processed: 9, Curr_docid: 101
#
# #### Model Parameters ####
# pred_tensor torch.Size([47, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5831083655357361
# Epoch: 1547, Converging-Loss: 0.24591732025146484
# Documents processed: 10, Curr_docid: 11
#
# #### Model Parameters ####
# pred_tensor torch.Size([36, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5870325565338135
# Epoch: 1234, Converging-Loss: 0.24935348331928253
# Documents processed: 11, Curr_docid: 61
#
# #### Model Parameters ####
# pred_tensor torch.Size([21, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5643126368522644
# Epoch: 1205, Converging-Loss: 0.26284515857696533
# Documents processed: 12, Curr_docid: 28
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.47038328647613525
# Epoch: 108, Converging-Loss: 0.362318754196167
# Documents processed: 13, Curr_docid: 186
#
# #### Model Parameters ####
# pred_tensor torch.Size([37, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5778015851974487
# Epoch: 1520, Converging-Loss: 0.23209242522716522
# Documents processed: 14, Curr_docid: 60
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6260737776756287
# Epoch: 1424, Converging-Loss: 0.2556856870651245
# Documents processed: 15, Curr_docid: 128
#
# #### Model Parameters ####
# pred_tensor torch.Size([39, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6303495168685913
# Epoch: 1478, Converging-Loss: 0.24404695630073547
# Documents processed: 16, Curr_docid: 31
#
# #### Model Parameters ####
# pred_tensor torch.Size([70, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5669026374816895
# Epoch: 1826, Converging-Loss: 0.28678154945373535
# Documents processed: 17, Curr_docid: 35
#
# #### Model Parameters ####
# pred_tensor torch.Size([45, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5474295020103455
# Epoch: 895, Converging-Loss: 0.2724120318889618
# Documents processed: 18, Curr_docid: 10
#
# #### Model Parameters ####
# pred_tensor torch.Size([13, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6621566414833069
# Epoch: 970, Converging-Loss: 0.3186725676059723
# Documents processed: 19, Curr_docid: 111
#
# #### Model Parameters ####
# pred_tensor torch.Size([52, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6488051414489746
# Epoch: 1795, Converging-Loss: 0.27112698554992676
# Documents processed: 20, Curr_docid: 33
#
# #### Model Parameters ####
# pred_tensor torch.Size([49, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6178730726242065
# Epoch: 1395, Converging-Loss: 0.2373400777578354
# Documents processed: 21, Curr_docid: 63
#
# #### Model Parameters ####
# pred_tensor torch.Size([72, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6272966861724854
# Epoch: 1307, Converging-Loss: 0.28629550337791443
# Documents processed: 22, Curr_docid: 34
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5623827576637268
# Epoch: 794, Converging-Loss: 0.2659490704536438
# Documents processed: 23, Curr_docid: 90
#
# #### Model Parameters ####
# pred_tensor torch.Size([29, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5465519428253174
# Epoch: 1123, Converging-Loss: 0.23821595311164856
# Documents processed: 24, Curr_docid: 6
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5691283941268921
# Epoch: 1244, Converging-Loss: 0.27517735958099365
# Documents processed: 25, Curr_docid: 121
#
# #### Model Parameters ####
# pred_tensor torch.Size([19, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4958992004394531
# Epoch: 1686, Converging-Loss: 0.25750473141670227
# Documents processed: 26, Curr_docid: 120
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5913558602333069
# Epoch: 895, Converging-Loss: 0.2518617808818817
# Documents processed: 27, Curr_docid: 55
#
# #### Model Parameters ####
# pred_tensor torch.Size([26, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6853536367416382
# Epoch: 1377, Converging-Loss: 0.29145801067352295
# Documents processed: 28, Curr_docid: 7
#
# #### Model Parameters ####
# pred_tensor torch.Size([16, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5881661176681519
# Epoch: 1345, Converging-Loss: 0.2523387372493744
# Documents processed: 29, Curr_docid: 110
#
# #### Model Parameters ####
# pred_tensor torch.Size([68, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.562147855758667
# Epoch: 1323, Converging-Loss: 0.25204575061798096
# Documents processed: 30, Curr_docid: 36
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.588455319404602
# Epoch: 1350, Converging-Loss: 0.2776610851287842
# Documents processed: 31, Curr_docid: 24
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6685608625411987
# Epoch: 914, Converging-Loss: 0.2489010989665985
# Documents processed: 32, Curr_docid: 254
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6293342113494873
# Epoch: 1300, Converging-Loss: 0.25125259160995483
# Documents processed: 33, Curr_docid: 57
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5745238661766052
# Epoch: 1118, Converging-Loss: 0.23181018233299255
# Documents processed: 34, Curr_docid: 280
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5480248928070068
# Epoch: 1016, Converging-Loss: 0.27817222476005554
# Documents processed: 35, Curr_docid: 30
#
# #### Model Parameters ####
# pred_tensor torch.Size([24, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6764138340950012
# Epoch: 1531, Converging-Loss: 0.282112181186676
# Documents processed: 36, Curr_docid: 124
#
# #### Model Parameters ####
# pred_tensor torch.Size([50, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6177704930305481
# Epoch: 1973, Converging-Loss: 0.26101914048194885
# Documents processed: 37, Curr_docid: 13
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6538082957267761
# Epoch: 1726, Converging-Loss: 0.28081926703453064
# Documents processed: 38, Curr_docid: 5
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6623401641845703
# Epoch: 1282, Converging-Loss: 0.2921375632286072
# Documents processed: 39, Curr_docid: 309
#
# #### Model Parameters ####
# pred_tensor torch.Size([98, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6137878894805908
# Epoch: 1462, Converging-Loss: 0.2926584780216217
# Documents processed: 40, Curr_docid: 14
#
# #### Model Parameters ####
# pred_tensor torch.Size([25, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6017427444458008
# Epoch: 1285, Converging-Loss: 0.2581021189689636
# Documents processed: 41, Curr_docid: 58
#
# #### Model Parameters ####
# pred_tensor torch.Size([10, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5302261114120483
# Epoch: 836, Converging-Loss: 0.30318379402160645
# Documents processed: 42, Curr_docid: 308
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5368386507034302
# Epoch: 1037, Converging-Loss: 0.2327934056520462
# Documents processed: 43, Curr_docid: 102
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5212985277175903
# Epoch: 784, Converging-Loss: 0.4021965563297272
# Documents processed: 44, Curr_docid: 189
#
# #### Model Parameters ####
# pred_tensor torch.Size([15, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.667931079864502
# Epoch: 1470, Converging-Loss: 0.3014758825302124
# Documents processed: 45, Curr_docid: 117
#
# #### Model Parameters ####
# pred_tensor torch.Size([22, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5647642612457275
# Epoch: 1353, Converging-Loss: 0.28269216418266296
# Documents processed: 46, Curr_docid: 53
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5229043364524841
# Epoch: 1156, Converging-Loss: 0.22881993651390076
# Documents processed: 47, Curr_docid: 23
#
# #### Model Parameters ####
# pred_tensor torch.Size([17, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5721438527107239
# Epoch: 1603, Converging-Loss: 0.25259944796562195
# Documents processed: 48, Curr_docid: 114
#
# #### Model Parameters ####
# pred_tensor torch.Size([34, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5342316627502441
# Epoch: 1405, Converging-Loss: 0.27151405811309814
# Documents processed: 49, Curr_docid: 27
#
# #### Model Parameters ####
# pred_tensor torch.Size([8, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6270304918289185
# Epoch: 1228, Converging-Loss: 0.25272390246391296
# Documents processed: 50, Curr_docid: 88
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4045979976654053
# Epoch: 474, Converging-Loss: 0.08009999990463257
# Documents processed: 51, Curr_docid: 39
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.6091960668563843
# Epoch: 777, Converging-Loss: 0.26548776030540466
# Documents processed: 52, Curr_docid: 281
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.35627490282058716
# Epoch: 71, Converging-Loss: 0.3373500108718872
# Documents processed: 53, Curr_docid: 207
#
# #### Model Parameters ####
# pred_tensor torch.Size([20, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5550980567932129
# Epoch: 890, Converging-Loss: 0.23995471000671387
# Documents processed: 54, Curr_docid: 25
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.800615668296814
# Epoch: 415, Converging-Loss: 0.38259997963905334
# Documents processed: 55, Curr_docid: 72
#
# #### Model Parameters ####
# pred_tensor torch.Size([12, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.7005385756492615
# Epoch: 1193, Converging-Loss: 0.2586498260498047
# Documents processed: 56, Curr_docid: 112
#
# #### Model Parameters ####
# pred_tensor torch.Size([27, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5144404172897339
# Epoch: 1385, Converging-Loss: 0.25723952054977417
# Documents processed: 57, Curr_docid: 127
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3669337034225464
# Epoch: 50, Converging-Loss: 0.34580981731414795
# Documents processed: 58, Curr_docid: 250
#
# #### Model Parameters ####
# pred_tensor torch.Size([30, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 1.2410085201263428
# Epoch: 322, Converging-Loss: 0.3691166639328003
# Documents processed: 232, Curr_docid: 190
#
# #### Model Parameters ####
# pred_tensor torch.Size([6, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5737754702568054
# Epoch: 698, Converging-Loss: 0.29009926319122314
# Documents processed: 233, Curr_docid: 270
#
# #### Model Parameters ####
# pred_tensor torch.Size([3, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.5793994069099426
# Epoch: 298, Converging-Loss: 0.3641597032546997
# Documents processed: 234, Curr_docid: 241
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.32786405086517334
# Epoch: 606, Converging-Loss: 0.20506668090820312
# Documents processed: 235, Curr_docid: 45
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.4037584066390991
# Epoch: 732, Converging-Loss: 0.2740499973297119
# Documents processed: 236, Curr_docid: 155
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.34533119201660156
# Epoch: 8, Converging-Loss: 0.3422333300113678
# Documents processed: 237, Curr_docid: 209
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.9199706315994263
# Epoch: 361, Converging-Loss: 0.32206666469573975
# Documents processed: 238, Curr_docid: 148
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.79253089427948
# Epoch: 245, Converging-Loss: 0.25110000371932983
# Documents processed: 239, Curr_docid: 303
#
# #### Model Parameters ####
# pred_tensor torch.Size([2, 2])
# ##########################
# Epoch: 1, Initial-Loss: 0.3600594401359558
# Epoch: 335, Converging-Loss: 0.25754186511039734
# Documents processed: 240, Curr_docid: 1

# %%
test_data['predicted_slider1'] = test_data.apply(lambda row: [round(row.predicted_b1,4) , 
                                                                round(row.predicted_e1,4)], axis=1)
test_data['predicted_slider2'] = test_data.apply(lambda row: [round(row.predicted_b2,4), 
                                                                round(row.predicted_e2,4)], axis=1)
test_data['predicted_timeml_coarse'] = test_data.apply(lambda row: time_ml_coarse(row, 
                                                             'predicted_slider1', 
                                                             'predicted_slider2'),
                                                                    axis=1)
test_data.drop(['predicted_b1','predicted_e1', 'predicted_b2',  'predicted_e2'],axis=1, inplace=True)
test_data.head()
print(test_data.shape)
# Out:
# (14910, 34)

# %%
## Restore only the top row by sent_token:
test_data = test_data.groupby(['sent_token']).first().reset_index()
print(test_data.shape)
    
## Replace duration and confidence values with median/mean values
test_data['pred1_duration'] = test_data.apply(lambda row: pred1_dur_dict[row.sent_token], axis=1)
test_data['pred2_duration'] = test_data.apply(lambda row: pred2_dur_dict[row.sent_token], axis=1)
test_data['pred1_dur_conf_ridit'] = test_data.apply(lambda row: pred1_dur_conf_dict[row.sent_token], axis=1)
test_data['pred2_dur_conf_ridit'] = test_data.apply(lambda row: pred2_dur_conf_dict[row.sent_token], axis=1)
test_data['relation_conf_ridit'] = test_data.apply(lambda row: rel_conf_dict[row.sent_token], axis=1)

## Drop variables that don't make sense:
cols_drop = ['worker_id', 'pred1_slider', 'pred2_slider', 
             'pred1_slider_lst', 'pred2_slider_lst',
            'time_ml_coarse', 'time_ml_code_coarse', 
            'norm_slider1', 'norm_slider2']

test_data = test_data.drop(cols_drop, axis=1)
# Out:
# (5112, 34)

# %%
test_data.to_pickle(data_path + "pre_processed/test_preprocessed.pkl")
save_obj(test_doc_timlines, "pre_processed/test_timelines.pkl")

# %% [markdown]
# ## 3. Predicted-Relations Statistics

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %%
match = sum(train_data['time_ml_coarse'] == train_data['predicted_timeml'])
total = train_data.shape[0]
print("% of Relations remained same: {}".format(match/total))
# Out:
# % of Relations remained same: 0.45959933222036725

# %%
time_tags = list(train_data['time_ml_coarse'].unique())

# %%
print(train_data.time_ml_coarse.value_counts())
sns.countplot(x='time_ml_coarse', order=time_tags, data=train_data)
plt.show()
# Out:
# before             17357
# includes           11058
# is_included         8899
# before_overlaps     5865
# simultaneous        5734
# after               4080
# after_overlaps       917
# Name: time_ml_coarse, dtype: int64

# %%
print(train_data.predicted_timeml.value_counts())
sns.countplot(x='predicted_timeml', order=time_tags, data=train_data)
plt.show()
# Out:
# before_overlaps    15872
# before             10261
# includes            9765
# is_included         9721
# after_overlaps      5676
# after               2608
# simultaneous           7
# Name: predicted_timeml, dtype: int64

# %% [markdown]
# ### 3.1 Confusion Matrix

# %%
time_tags = train_data.time_ml_coarse.unique()
time_tags
# Out:
# [before, simultaneous, is_included, after, includes, before_overlaps, after_overlaps]
# Categories (7, object): [before, simultaneous, is_included, after, includes, before_overlaps, after_overlaps]

# %%
conf_matrix = confusion_matrix(train_data.time_ml_coarse, train_data.predicted_timeml, labels=time_tags)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_matrix, classes=time_tags, normalize=False,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[8372    0 1699  246 1060 5501  479]
#  [ 206    7 1261   86 1331 1732 1111]
#  [ 373    0 4820  175  493 2039  999]
#  [ 107    0  336 1776  410  295 1156]
#  [ 521    0  692  184 5756 2700 1205]
#  [ 661    0  811   68  557 3544  224]
#  [  21    0  102   73  158   61  502]]

# %% [markdown]
# ## 4. Document Timeline - Example

# %%
def extract_pred_text(lst, data):
    '''
    Input: A list of sent_pred tokens
    Output: A list of predicate text
    '''
    ans = []
    for sent_pred in lst:
        try:
            pred_text = data[(data.sent_pred_id1==sent_pred)]['pred1_text'].values[0]
            ans.append(pred_text)
        except:
            pred_text = data[(data.sent_pred_id2==sent_pred)]['pred2_text'].values[0]
            ans.append(pred_text)
            
    return ans

def extract_timeline_df(docid, data):
    '''
    Extract a timeline_df for a given docid and data
    '''
    cols = ['sent_pred_id1', 'sent_pred_id2', 'pred1_text', 'pred2_text',
            'doc_id', 'norm_slider1', 'norm_slider2']
    
    local_data = data[(data.doc_id == docid)][cols]
    preds_arr = local_data[['sent_pred_id1', 'sent_pred_id2']].values
    uniq_preds = np.unique(preds_arr.flatten())
    #print(uniq_preds)
    
    preds_text = extract_pred_text(uniq_preds, local_data)
    
    ans_df = pd.DataFrame(data=train_doc_timlines[docid], 
                         columns=['start_pt', 'duration'])
    ans_df['sent_pred_id'] = uniq_preds
    ans_df['pred_text'] = preds_text
    ans_df['doc_id'] = docid
    
    return ans_df

def load_ud_english(fpath):
    """Load a file from the UD English corpus

    Parameters
    ----------
    fpath : str
        Path to UD corpus file ending in .conllu
        
    Output: Returns a list equal to length of total num of docs
            with each item contaiing the first index of sentence
            in that doc
    """

    n = 1

    fname = os.path.split(fpath)[1]

    parses = defaultdict(list)
    sent_ids = []
    newdoc_ids = []
    
    for l in open(fpath):
        ident = fname+' '+str(n)
        
        if re.match(r'\# newdoc id', l):
            newdoc_ids.append(n)
            #newdoc_ids.append(l.split("=")[-1].strip())
            
        if re.match(r'^\d', l):
            l_split = l.strip().split()
            parses[ident].append(l_split)
        
        elif parses[ident]:
            sent_ids.append(ident)
            n += 1

    return newdoc_ids, len(sent_ids)

def extract_sent_to_docid_dict(path_list):
    '''
    Input: ewt_ud .conllu file path
    
    Output: A dict with keys: sent_id, value: doc_id
    '''
    sent_to_doc_dict = {}
    
    for ud_ewt_path in path_list:
        doc_lst, total_sents = load_ud_english(ud_ewt_path)
        data_name = ud_ewt_path.split("ud-")[-1].split(".")[0]
        string = "en-ud-" + data_name + ".conllu" + " "

        len_doc_lst = len(doc_lst)
        
        for i in range(len_doc_lst-1):
            for sent_idx in range(doc_lst[i], doc_lst[i+1]):
                sent_to_doc_dict[string + str(sent_idx)] = str(i+1)

        #Last document:
        for sent_idx in range(doc_lst[-1], total_sents+1):
            sent_to_doc_dict[string + str(sent_idx)] = str(len_doc_lst)
    
    return sent_to_doc_dict

def extract_docid_to_sentid_dict(path_list):
    '''
    Input: ewt_ud .conllu file path
    
    Output: A dict with keys: sent_id, value: doc_id
    '''
    doc_to_sent_dict = {}
    
    for ud_ewt_path in path_list:
        doc_lst, total_sents = load_ud_english(ud_ewt_path)
        data_name = ud_ewt_path.split("ud-")[-1].split(".")[0]
        string = "en-ud-" + data_name + ".conllu" + " "

        len_doc_lst = len(doc_lst)
        
        #Data dict
        doc_to_sent_dict[data_name] = defaultdict(list)
        
        for i in range(len_doc_lst-1):
            for sent_idx in range(doc_lst[i], doc_lst[i+1]):
                sent_string = string + "sent_" + str(sent_idx)
                doc_to_sent_dict[data_name][i+1].append(sent_string)

        #Last document:
        for sent_idx in range(doc_lst[-1], total_sents+1):
            sent_string = string + "sent_" + str(sent_idx)
            doc_to_sent_dict[data_name][len_doc_lst].append(sent_string)
                
    return doc_to_sent_dict

# %%
extract_timeline_df(353, train_data).to_csv("timeline_example.csv", index=False)

# %%
extract_timeline_df(353, train_data)
# Out:
#     start_pt  duration                 sent_pred_id        pred_text  doc_id
# 0   0.107253  0.129046   en-ud-train.conllu 10690 2              got     353
# 1   0.464634  1.080031   en-ud-train.conllu 10690 9           missed     353
# 2   0.611661  0.145337  en-ud-train.conllu 10691 18   was so excited     353
# 3   0.722593  0.404707  en-ud-train.conllu 10691 21           wanted     353
# 4   0.797044  0.373317  en-ud-train.conllu 10691 23               go     353
# 5   0.000000  2.158159  en-ud-train.conllu 10691 25             test     353
# 6   0.315186  0.099849   en-ud-train.conllu 10691 4             told     353
# 7   0.066097  0.497601   en-ud-train.conllu 10692 4      was perfect     353
# 8   0.270688  0.037692   en-ud-train.conllu 10693 3  was better then     353
# 9   0.075254  0.232085   en-ud-train.conllu 10693 9           tasted     353
# 10  1.609003  0.271031   en-ud-train.conllu 10695 3        recommend     353
# 11  0.503782  0.619231   en-ud-train.conllu 10695 8          looking     353
# 12  4.252300  3.683471   en-ud-train.conllu 10696 0            Thank     353

# %% [markdown]
# ## Extract Doc-Sentences

# %%
ud_ewt_paths = [ud_train_detailed, ud_dev_detailed, ud_test_detailed]
#sent_to_docid_dict = extract_sent_to_docid_dict(ud_ewt_paths)
doc_to_sent_dict = extract_docid_to_sentid_dict(ud_ewt_paths)

# %%
for sent in doc_to_sent_dict['train'][353]:
    print(" ".join(struct_dict[sent].sentence))
# Out:
# AMAZINGLY YUMMY !
# I just got back from france yesterday and just missed the food already !
# My sister in law told me about this amazing new crepe place in town , I was so excited I just wanted to go and test it out for my self !
# Their customer service was perfect !
# Their Food was better then anything I had ever tasted .
# EVEN IN FRANCE !
# I would highly recommend this place to anyone looking for a great atmosphere , amazing food , and great customer service !
# Thank you Roll UP Crepes !

# %% [markdown]
# ## Rough for debugging

# %% [markdown]
# ## Run an example

# %%
# split_data= "dev"
# doc_id = 9

# %%
# pred_dict, num_preds, local_data = extract_preds(doc_id, out_data, split_data=split_data)
# print(num_preds)
# local_data.head()

# %%
# # Run Timeline Model on current docid's data
# model = TimelineModel(data = local_data,
#          num_preds = num_preds,
#         device=torch.device(type="cpu"))

# pred_b1, pred_e1, pred_b2, pred_e2, pred_timeline  = model.fit(local_data, epochs=100000)
# #doc_timelines[doc_id] = pred_timeline

# %%
# len(pred_b1)

# %%
# pred_timeline.shape

# %%
# data_mod = out_data[out_data.split==split_data]

# %%
# data_mod.shape

# %%
# ## Store prediction-values into the dataset
# data_mod.loc[(data_mod.doc_id == doc_id), 
#              'predicted_b1'] = pred_b1

# data_mod.loc[(data_mod.doc_id == doc_id), 
#              'predicted_e1'] = pred_e1

# data_mod.loc[(data_mod.doc_id == doc_id), 
#              'predicted_b2'] = pred_b2

# data_mod.loc[(data_mod.doc_id == doc_id), 
#              'predicted_e2'] = pred_e2

# ## Restore only the top row by doc_id and sent_token:
# data_mod = data_mod.groupby(['sent_token']).first().reset_index()
    
    
# ## Replace duration and confidence values with median/mean values
# data_mod['pred1_duration'] = data_mod.apply(lambda row: pred1_dur_dict[row.sent_token], axis=1)
# data_mod['pred2_duration'] = data_mod.apply(lambda row: pred2_dur_dict[row.sent_token], axis=1)
# data_mod['pred1_dur_conf'] = data_mod.apply(lambda row: pred1_dur_conf_dict[row.sent_token], axis=1)
# data_mod['pred2_dur_conf'] = data_mod.apply(lambda row: pred2_dur_conf_dict[row.sent_token], axis=1)
# data_mod['relation_conf'] = data_mod.apply(lambda row: rel_conf_dict[row.sent_token], axis=1)

# ## Drop variables that don't make sense:
# cols_drop = ['worker_id', 'pred1_slider', 'pred2_slider', 
#              'pred1_slider_lst', 'pred2_slider_lst',
#             'time_ml_coarse', 'time_ml_code_coarse', 
#             'norm_slider1', 'norm_slider2']

# data_mod = data_mod.drop(cols_drop, axis=1)

# %%
# data_mod.shape

# %%
# sent_token = 'en-ud-dev.conllu 74_22 en-ud-dev.conllu 74_25'
# data_mod.loc[(data_mod.doc_id == doc_id) &
#             (data_mod.sent_token==sent_token)]
