# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from nltk.metrics.agreement import AnnotationTask
from sklearn.metrics import cohen_kappa_score as kappa
from sklearn.metrics import accuracy_score as accuracy
from scipy.stats import pearsonr as pearson
from scipy.stats import spearmanr as spearman
from math import isnan

# %%
pilot_file = "pilot_results_May5.csv"
data = pd.read_csv(pilot_file)
data.columns = [c.replace('.', '_') for c in data.columns]

# %%
def extract_dataframe(data):
    '''
    Input: Pandas csv dataframe obtained from MTurk
    
    Output: Pandas dataframe levelled by (User x Sentenced_ID)
    '''
    data["dicts"] = data["Input_var_arrays"].map(lambda x: json.loads(x))
    global_list = []
    
    for row in data.itertuples():
        for idx, local_dict in enumerate(row.dicts):
            temp_dict = local_dict.copy()
            var_dyn = "Answer_pred_dynamicity" + str(idx + 1)
            var_dyn_c = "Answer_dynamicity_certainty" + str(idx + 1)
            var_part = "Answer_pred_particular" + str(idx + 1)
            var_part_c = "Answer_particular_certainty" + str(idx + 1)
            temp_dict['part'] = getattr(row, var_part)
            temp_dict['part_conf'] = getattr(row, var_part_c)
            temp_dict['dyn'] = getattr(row, var_dyn)
            temp_dict['dyn_conf'] = getattr(row, var_dyn_c)
            temp_dict['worker_id'] = row.WorkerId
            temp_dict['hit_id'] = row.HITId
            global_list.append(temp_dict)
    
    return pd.DataFrame(global_list)

# %%
raw_data = extract_dataframe(data)
# Rearrange the columns
cols = ['hit_id', 'worker_id','sent_pred','sent_id','pred_token','part','part_conf',
        'dyn','dyn_conf']
raw_data['sent_pred'] = raw_data['sent_id'].map(lambda x : x) + "_" +\
                           raw_data['pred_token'].map(lambda x: str(x))
pilot_data = raw_data[cols]
pilot_data.head()
# Out:
#                            hit_id       worker_id  \
# 0  3O71U79SRBUX47IF48NW304Z4TCSMT  A2WLGVXAVT2XTR
# 1  3O71U79SRBUX47IF48NW304Z4TCSMT  A2WLGVXAVT2XTR
# 2  3O71U79SRBUX47IF48NW304Z4TCSMT  A2WLGVXAVT2XTR
# 3  3O71U79SRBUX47IF48NW304Z4TCSMT  A2WLGVXAVT2XTR
# 4  3O71U79SRBUX47IF48NW304Z4TCSMT  A2WLGVXAVT2XTR
#
#                         sent_pred                       sent_id pred_token  \
# 0  en-ud-train.conllu sent_8206_4  en-ud-train.conllu sent_8206          4
# 1  en-ud-train.conllu sent_5978_3  en-ud-train.conllu sent_5978          3
# 2  en-ud-train.conllu sent_6541_3  en-ud-train.conllu sent_6541          3
# 3  en-ud-train.conllu sent_7297_0  en-ud-train.conllu sent_7297          0
# 4    en-ud-dev.conllu sent_1464_2    en-ud-dev.conllu sent_1464          2
#
#    part  part_conf    dyn  dyn_conf
# 0  True          4  False         4
# 1  True          2  False         4
# 2  True          3   True         3
# 3  True          4   True         4
# 4  True          4   True         4

# %%
# %matplotlib inline

print(pilot_data.pivot_table(index=['part', 'dyn'], 
                                  columns='dyn_conf', 
                                  values='worker_id', aggfunc=len))
sns.heatmap(pilot_data.pivot_table(index=['part', 'dyn'], 
                                  columns='dyn_conf', 
                                  values='worker_id', aggfunc=len).fillna(0))
# Out:
# dyn_conf       0     1     2     3     4
# part  dyn
# False False  2.0  10.0  41.0  43.0  59.0
#       True   NaN   5.0  23.0  17.0  35.0
# True  False  NaN   7.0  27.0  26.0  73.0
#       True   NaN   5.0  44.0  30.0  53.0

# %% [markdown]
# ### Response distribution

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(10, 10))
sns.countplot(x='part', data=pilot_data, ax=axs[0][0])
sns.countplot(x='part_conf', data=pilot_data, ax=axs[0][1])
sns.countplot(x='dyn', data=pilot_data, ax=axs[1][0])
sns.countplot(x='dyn_conf', data=pilot_data, ax=axs[1][1])

plt.show()

# %% [markdown]
# ## Inter Annotator agreement

# %% [markdown]
# ## Raw agreement

# %%
def calc_raw_agreement(data, key_var, check_var):
    '''
    Input: 
    1. data: Pandas dataframe
    2. key_var: variable based on which raw agreement is to be calculated
    3. check_var: vaiable on which raw agreement is calculated
    
    '''
    print("####### Raw Count for {} ###########".format(check_var))
    ids = set(list(data[key_var].values))

    total_count = len(ids)
    raw_count = 0
    keys = []
    
    for iden in ids:
        temp = list(data[data[key_var] == iden][check_var].values)
        if temp.count(temp[0]) == len(temp):
            raw_count += 1
            keys.append(iden)
     
    agreement = (raw_count/total_count)*100
    
    print("Total count of unique {} is {}".format(key_var, total_count))
    print("Raw count of matched for {} is {}".format(check_var, raw_count))
    print("Inter-annotator agreement for {} is {}%".format(check_var, agreement))
    print("\n")
    
    return agreement, keys
instant_agreement, key_inst = calc_raw_agreement(pilot_data, 'sent_pred', 'part')
start_agreement, key_start = calc_raw_agreement(pilot_data, 'sent_pred', 'dyn')
# Out:
# ####### Raw Count for part ###########
# Total count of unique sent_pred is 100
# Raw count of matched for part is 13
# Inter-annotator agreement for part is 13.0%
#
#
# ####### Raw Count for dyn ###########
# Total count of unique sent_pred is 100
# Raw count of matched for dyn is 32
# Inter-annotator agreement for dyn is 32.0%

# %% [markdown]
# ## Average of accuracy and kappa for each pair

# %%
def extract_pairs_of_workers(data, worker_id):
    '''
    Given a pandas dataframe, and worker_id variable,
    extracts a list of pairs of worker_ids
    '''
    workers = list(set(data[worker_id].values))
    
    return list(itertools.combinations(workers, 2))

def extract_worker_sent_dict(data, worker_id, sent_id):
    '''
    Given a pandas dataframe, worker_id variable, and sentence_id variable,
    extracts a dict where key is worker_id and value is set(sentences_ids annotated by that worker)
    
    '''
    workers = list(set(data[worker_id].values))
    
    ans = {}
    
    for worker in workers:
        sents = set(list(data[data[worker_id] == worker][sent_id].values))
        ans[worker] = sents
        
    return ans

def average_kappa_acc(data, worker_id, key_var, check_var):
    '''
    Input: 1. data: pandas dataframe
           2. worker_id: Annotator id variable
           3. key_var: level of the data (sentence-predicate id)
           4. check_var: variable to be checked for kappa score
    
    Output: kappa score and average accuracy for (pairs of annotators) in the dataset

    '''
    worker_pairs = extract_pairs_of_workers(data, worker_id)
    
    worker_key_dict = extract_worker_sent_dict(data, worker_id, key_var)
    
    kappas = []
    accuracies = []
    lens = []
    for (w1, w2) in worker_pairs:
        
        common_set = worker_key_dict[w1].intersection(worker_key_dict[w2])
        temp1 = []
        temp2 = []
        
        if common_set == set():
            continue
        if len(common_set) == 150:
            print(w1, w2)
        for key in common_set:
            val1 = data[(data[key_var] == key) & 
                        (data[worker_id] == w1)][check_var].values
            val2 = data[(data[key_var] == key) & 
                        (data[worker_id] == w2)][check_var].values

            temp1.append(val1[0])
            temp2.append(val2[0])

        kappas.append(kappa(temp1, temp2))
        accuracies.append(accuracy(temp1, temp2))
        lens.append(len(temp1))
    return kappas, accuracies

def rank_correlation(data, worker_id, key_var, check_var):
    '''
    Input: 1. data: pandas dataframe
           2. worker_id: Annotator id variable
           3. key_var: level of the data (sentence-predicate id)
           4. check_var: variable to be checked for kappa score
    
    Output: pearson rank correlation

    '''
    worker_pairs = extract_pairs_of_workers(data, worker_id)
    
    worker_key_dict = extract_worker_sent_dict(data, worker_id, key_var)
    
    corrs = []
    accuracies = []
    for (w1, w2) in worker_pairs:
        
        common_set = worker_key_dict[w1].intersection(worker_key_dict[w2])
        temp1 = []
        temp2 = []
        
        if common_set == set():
            continue

        for key in common_set:
            val1 = data[(data[key_var] == key) & 
                        (data[worker_id] == w1)][check_var].values
            val2 = data[(data[key_var] == key) & 
                        (data[worker_id] == w2)][check_var].values

            temp1.append(val1[0])
            temp2.append(val2[0])

        corrs.append(spearman(temp1, temp2)[0])
        accuracies.append(accuracy(temp1, temp2))
        
    return corrs, accuracies

# %%
kappas = {}
corrs = {}
accs = {}
variables = ['part', 'dyn']
variables_ord = ['part_conf', 'dyn_conf']
for var in variables:
    kappas[var], accs[var] = average_kappa_acc(pilot_data, 'worker_id', 'sent_pred', var)

for var in variables_ord:
    corrs[var], accs[var] = rank_correlation(pilot_data, 'worker_id', 'sent_pred', var)
# Out:
# /Users/venkat/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/venkat/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /Users/venkat/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
kappa_data = pd.DataFrame.from_dict(kappas)
acc_data = pd.DataFrame.from_dict(accs)
corr_data = pd.DataFrame.from_dict(corrs)

ax = sns.boxplot(data=kappa_data)
ax.set(ylabel='Kappa Score using builtin function', title="Kappa")
plt.show()
print(np.mean(kappa_data))

ax = sns.boxplot(data=acc_data)
ax.set(ylabel='Accuracy(raw agreement)', title="Accuracy")
plt.show()
print(np.mean(acc_data))

ax = sns.boxplot(data=corr_data)
ax.set(ylabel='Corr coeff', title="Pearsons/Spearman Rank Correlation")
plt.show()
print(np.mean(corr_data))
# Out:
# part    0.087961
# dyn     0.264916
# dtype: float64
# part         0.540509
# dyn          0.617017
# part_conf    0.282639
# dyn_conf     0.292890
# dtype: float64
# part_conf    0.054703
# dyn_conf     0.060666
# dtype: float64

# %% [markdown]
# # Run mixed effects model in R

# %%
# Enables the %%R magic 
# %load_ext rpy2.ipython
# %R require(ggplot2); require(tidyr); require(lme4)
# Out:
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: tidyr
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: lme4
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required package: Matrix
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘Matrix’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/venkat/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
#   warnings.warn(x, RRuntimeWarning)
# array([1], dtype=int32)

# %% [markdown]
# ## Part

# %%
# %%R -i pilot_data -o df_part
#
# #Convert to factors
# pilot_data$part = as.factor(pilot_data$part)
# pilot_data$dyn = as.factor(pilot_data$dyn)
#
# #Mixed Effects Model
# model = glmer(part ~ 1 + (1|worker_id) + (1|sent_pred) + (1|hit_id), data=pilot_data,  family=binomial)
#
# #Model intercepts:
# df_part = ranef(model)$worker_id
# colnames(df_part) <- c('intercept')
#
# df_part$glmer_intercept_part = df_part$intercept + 0.4795 #constant added manually
# df_part$worker_id <- rownames(df_part)
# print(summary(model))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: part ~ 1 + (1 | worker_id) + (1 | sent_pred) + (1 | hit_id)
#    Data: pilot_data
#
#      AIC      BIC   logLik deviance df.resid
#    548.6    565.5   -270.3    540.6      496
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4885 -0.5518  0.2126  0.5406  2.8646
#
# Random effects:
#  Groups    Name        Variance Std.Dev.
#  sent_pred (Intercept) 1.1535   1.0740
#  worker_id (Intercept) 2.5783   1.6057
#  hit_id    (Intercept) 0.1833   0.4281
# Number of obs: 500, groups:  sent_pred, 100; worker_id, 19; hit_id, 10
#
# Fixed effects:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   0.8402     0.4475   1.878   0.0604 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
df_part['glmer_intercept_part'] = df_part['glmer_intercept_part'].apply(lambda x: 1/(1+np.exp(-x)))

# %%
df_part.glmer_intercept_part.plot(kind='density')
plt.title("Annotator probability density of saying part = true")
plt.show()

# %% [markdown]
# ## Dynamic

# %%
# %%R -i pilot_data -o df_dyn
#
# #Convert to factors
# pilot_data$part = as.factor(pilot_data$part)
# pilot_data$dyn = as.factor(pilot_data$dyn)
# #Mixed Effects Model
# model = glmer(dyn ~ 1 + (1|worker_id) + (1|sent_pred) + (1|hit_id), data=pilot_data,  family="binomial")
#
# #Model intercepts:
# df_dyn = ranef(model)$worker_id
# colnames(df_dyn) <- c('intercept')
#
# df_dyn$glmer_intercept_dyn = df_dyn$intercept - 0.2052 #constant added manually
# df_dyn$worker_id <- rownames(df_dyn)
#
# print(summary(model))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: dyn ~ 1 + (1 | worker_id) + (1 | sent_pred) + (1 | hit_id)
#    Data: pilot_data
#
#      AIC      BIC   logLik deviance df.resid
#    575.0    591.8   -283.5    567.0      496
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0231 -0.4706 -0.2194  0.5104  2.7985
#
# Random effects:
#  Groups    Name        Variance  Std.Dev.
#  sent_pred (Intercept) 4.363e+00 2.089e+00
#  worker_id (Intercept) 1.601e+00 1.265e+00
#  hit_id    (Intercept) 2.026e-10 1.423e-05
# Number of obs: 500, groups:  sent_pred, 100; worker_id, 19; hit_id, 10
#
# Fixed effects:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   0.1055     0.3988   0.265    0.791

# %%
df_dyn['glmer_intercept_dyn'] = df_dyn['glmer_intercept_dyn'].apply(lambda x: 1/(1+np.exp(-x)))

# %%
df_dyn.glmer_intercept_dyn.plot(kind='density')
plt.title("Annotator probability density of saying dynamic = true")
plt.show()

# %%
def extract_pairs_of_workers1(data, worker_id):
    '''
    Given a pandas dataframe, and worker_id variable,
    extracts a list of pairs of worker_ids
    '''
    workers = list(set(data[worker_id].values))
    
    return list(itertools.combinations(workers, 2))

def extract_worker_sent_dict1(data, worker_id, sent_id):
    '''
    Given a pandas dataframe, worker_id variable, and sentence_id variable,
    extracts a dict where key is worker_id and value is set(sentences_ids annotated by that worker)
    
    '''
    workers = list(set(data[worker_id].values))
    
    ans = {}
    
    for worker in workers:
        sents = set(list(data[data[worker_id] == worker][sent_id].values))
        ans[worker] = sents
        
    return ans

def average_kappa_acc1(data, worker_id, key_var, check_var):
    '''
    Input: 1. data: pandas dataframe
           2. worker_id: Annotator id variable
           3. key_var: level of the data (sentence-predicate id)
           4. check_var: variable to be checked for kappa score
    
    Output: kappa score and average accuracy for (pairs of annotators) in the dataset

    '''
    worker_pairs = extract_pairs_of_workers1(data, worker_id)
    
    worker_key_dict = extract_worker_sent_dict1(data, worker_id, key_var)
    if check_var == "part":
        df = df_part
        int_prob = "glmer_intercept_part"
    elif check_var == "dyn":
        df = df_dyn
        int_prob = "glmer_intercept_dyn"

    kappas = []
    accuracies = []
    for (w1, w2) in worker_pairs:
        
        common_set = worker_key_dict[w1].intersection(worker_key_dict[w2])
        temp1 = []
        temp2 = []
        
        if common_set == set():
            continue

        for key in common_set:
            val1 = data[(data[key_var] == key) & 
                        (data[worker_id] == w1)][check_var].values
            val2 = data[(data[key_var] == key) & 
                        (data[worker_id] == w2)][check_var].values

            temp1.append(val1[0])
            temp2.append(val2[0])
        accuracies.append(accuracy(temp1, temp2))
        # Now for modified kappa calculation
        p_e = (df[df[worker_id] == w1][int_prob][0] * df[df[worker_id] == w2][int_prob][0]) + ((1 - df[df[worker_id] == w1][int_prob][0]) * (1 - df[df[worker_id] == w2][int_prob][0]))
        kappas.append((accuracies[-1] - p_e) / (1 - p_e))
        
    return kappas

# %%
kappas = {}
corrs = {}
accs = {}
variables = ['part', 'dyn']
# variables_ord = ['part_conf', 'kind_conf', 'abs_conf']
for var in variables:
    kappas[var] = average_kappa_acc1(pilot_data, 'worker_id', 'sent_pred', var)

# %%
kappa_data = pd.DataFrame.from_dict(kappas)

ax = sns.boxplot(data=kappa_data)
ax.set(ylabel='Kappa Score', title="Kappa from mixed effects mode")
plt.show()

print("KAPPA", np.mean(kappa_data))
# Out:
# KAPPA part    0.154773
# dyn     0.227350
# dtype: float64

# %% [markdown]
# ## Check if average confidence correlates with agreement

# %%
xyz = list(set(raw_data['sent_pred'].values))
raw_data[raw_data['sent_pred'] == "en-ud-train.conllu sent_5978_3"]
# Out:
#       dyn  dyn_conf                          hit_id  id   part  part_conf  \
# 1   False         4  3O71U79SRBUX47IF48NW304Z4TCSMT   2   True          2
# 11  False         4  3O71U79SRBUX47IF48NW304Z4TCSMT   2  False          4
# 21  False         4  3O71U79SRBUX47IF48NW304Z4TCSMT   2  False          4
# 31  False         2  3O71U79SRBUX47IF48NW304Z4TCSMT   2  False          3
# 41  False         4  3O71U79SRBUX47IF48NW304Z4TCSMT   2  False          3
#
#    pred                                      pred_sentence pred_token  \
# 1    is  Yet , there <span class=\"predicate\">is</span...          3
# 11   is  Yet , there <span class=\"predicate\">is</span...          3
# 21   is  Yet , there <span class=\"predicate\">is</span...          3
# 31   is  Yet , there <span class=\"predicate\">is</span...          3
# 41   is  Yet , there <span class=\"predicate\">is</span...          3
#
#                                          raw_sentence  \
# 1   Yet , there is warmth and a familiarity with t...
# 11  Yet , there is warmth and a familiarity with t...
# 21  Yet , there is warmth and a familiarity with t...
# 31  Yet , there is warmth and a familiarity with t...
# 41  Yet , there is warmth and a familiarity with t...
#
#                          sent_id       worker_id  \
# 1   en-ud-train.conllu sent_5978  A2WLGVXAVT2XTR
# 11  en-ud-train.conllu sent_5978  A36O6HV8LCXLJR
# 21  en-ud-train.conllu sent_5978   AKTQD9Y44G495
# 31  en-ud-train.conllu sent_5978  A3HTLXAPOBCVVO
# 41  en-ud-train.conllu sent_5978  A11QDNT3W7DT7K
#
#                          sent_pred
# 1   en-ud-train.conllu sent_5978_3
# 11  en-ud-train.conllu sent_5978_3
# 21  en-ud-train.conllu sent_5978_3
# 31  en-ud-train.conllu sent_5978_3
# 41  en-ud-train.conllu sent_5978_3

# %%
all_list=[]

for question in list(set(pilot_data.sent_pred)):
    temp = {}
    temp['sent_pred'] = question
    temp['part_avg_confidence'] = np.mean(list(pilot_data[pilot_data["sent_pred"] == question]['part_conf']))
    temp['dyn_avg_confidence'] = np.mean(list(pilot_data[pilot_data["sent_pred"] == question]['dyn_conf']))
    p = sum(list(pilot_data[pilot_data["sent_pred"] == question]['part'].astype(int))) / 5
    q = sum(list(pilot_data[pilot_data["sent_pred"] == question]['dyn'].astype(int))) / 5
    temp['part_agreement'] = p * p + (1 - p) * (1 - p)
    temp['dyn_agreement'] = q * q + (1 - q) * (1 - q)
    all_list.append(temp)
analyse_data = pd.DataFrame(all_list)
print(spearman(list(analyse_data['dyn_agreement']), list(analyse_data['dyn_avg_confidence'])))
print(spearman(list(analyse_data['part_agreement']), list(analyse_data['part_avg_confidence'])))
# Out:
# SpearmanrResult(correlation=0.2873015756221566, pvalue=0.0037523817146645163)
# SpearmanrResult(correlation=0.13160979169178652, pvalue=0.19181221641853272)

# %% [markdown]
# ## Random Checking

# %%
cols = ['raw_sentence', 'part', 'part_conf', 'dyn','dyn_conf','hyp','hyp_conf']
# check_data = raw_data[cols]
for sen in xyz:
#     print(check_data[raw_data['sent_pred'] == sen])
    print(str(set(raw_data[raw_data['sent_pred'] == sen]['raw_sentence'].values)), str(set(raw_data[raw_data['sent_pred'] == sen]['pred'].values)))
    print("PART", sum(list(raw_data[raw_data['sent_pred'] == sen]['part'].astype(int)))/5, "CONF", sum(list(raw_data[raw_data['sent_pred'] == sen]['part_conf'].values))/5, "\t\t",
          "DYN", sum(list(raw_data[raw_data['sent_pred'] == sen]['dyn'].astype(int)))/5, "CONF", sum(list(raw_data[raw_data['sent_pred'] == sen]['dyn_conf'].values))/5,"\n\n")
# Out:
# {'A Sussex crossed with Silkie would make a crossbred * mutt * chicken .'} {'make'}
# PART 0.6 CONF 3.2 		 DYN 0.6 CONF 3.4
#
#
# {'Please contact me with any questions .'} {'contact'}
# PART 0.4 CONF 2.8 		 DYN 0.8 CONF 3.4
#
#
# {'As concerned citizens we affirm the liberty of adults of the same gender to love and marry .'} {'affirm'}
# PART 0.6 CONF 3.0 		 DYN 0.6 CONF 3.2
#
#
# {'<< There were no Jews in England to speak of in the 1590&#39;s .'} {'were'}
# PART 0.2 CONF 2.2 		 DYN 0.0 CONF 2.8
#
#
# {'How do you make your cat adjust to a new house ?'} {'make'}
# PART 0.6 CONF 3.4 		 DYN 0.2 CONF 3.2
#
#
# {'Plaster of Paris does two things'} {'does'}
# PART 0.6 CONF 3.4 		 DYN 0.4 CONF 3.2
#
#
# {'Tropical species have moved up to Florida and the Gulf Coast .'} {'moved'}
# PART 0.6 CONF 2.8 		 DYN 1.0 CONF 3.4
#
#
# {'This is an invention of the scammers . &quot;'} {'is'}
# PART 0.6 CONF 2.6 		 DYN 0.2 CONF 3.2
#
#
# {'Where in the world is Iguazu ?'} {'is'}
# PART 0.4 CONF 3.8 		 DYN 0.0 CONF 4.0
#
#
# {'I crave those .'} {'crave'}
# PART 0.6 CONF 3.4 		 DYN 0.6 CONF 2.8
#
#
# {'For those who believe ....................'} {'believe'}
# PART 0.4 CONF 3.8 		 DYN 0.2 CONF 3.2
#
#
# {'But iPhone was the first &quot; Officiol &quot; touch screen smart phone .'} {'was'}
# PART 0.8 CONF 3.4 		 DYN 0.0 CONF 3.2
#
#
# {'If you have any questions or comments , please advise .'} {'have'}
# PART 0.6 CONF 2.2 		 DYN 0.4 CONF 3.0
#
#
# {'My trader is supporting her price of SJ Bondad GDP rather than SJ Non-Bondad GDP .'} {'supporting'}
# PART 0.8 CONF 2.8 		 DYN 0.8 CONF 3.0
#
#
# {'Now I &#39;m able to play the piano pretty well .'} {'&#39;m'}
# PART 0.6 CONF 2.6 		 DYN 0.2 CONF 2.2
#
#
# {'Wolves can migrate considerable distances .'} {'migrate'}
# PART 0.0 CONF 3.4 		 DYN 1.0 CONF 4.0
#
#
# {'The food tasted like rat feces'} {'tasted'}
# PART 0.6 CONF 3.0 		 DYN 1.0 CONF 3.0
#
#
# {'He reportedly treated them like sons .'} {'treated'}
# PART 0.2 CONF 3.4 		 DYN 0.4 CONF 3.4
#
#
# {'&quot; Success comes before work &quot; only in the dictionary'} {'comes'}
# PART 0.2 CONF 2.6 		 DYN 0.2 CONF 2.6
#
#
# {'They even want to go to school on the weekends !!'} {'want'}
# PART 0.4 CONF 2.4 		 DYN 0.4 CONF 2.8
#
#
# {'Walk 2 blocks then turn right again .'} {'Walk'}
# PART 1.0 CONF 3.8 		 DYN 1.0 CONF 4.0
#
#
# {'We do need a formal plan .'} {'need'}
# PART 0.6 CONF 3.0 		 DYN 0.0 CONF 3.6
#
#
# {'What was the goal for North Vietnam in the Tet offensive ?'} {'was'}
# PART 0.6 CONF 2.8 		 DYN 0.2 CONF 3.2
#
#
# {'just go here , it s simply amazing'} {'s'}
# PART 0.4 CONF 3.4 		 DYN 0.0 CONF 3.6
#
#
# {'One of the worst experiences I &#39;ve ever had with a auto repair shop .'} {'had'}
# PART 1.0 CONF 3.4 		 DYN 0.2 CONF 3.0
#
#
# {'I extend my hand to each of you in true friendship , and honor .'} {'extend'}
# PART 0.6 CONF 3.0 		 DYN 1.0 CONF 3.0
#
#
# {'A spokesman for President Clinton also criticized Bush &#39;s comments .'} {'criticized'}
# PART 1.0 CONF 3.6 		 DYN 1.0 CONF 3.6
#
#
# {'Can a government listen to phone conversations of terrorists and drug dealers ?'} {'listen'}
# PART 0.6 CONF 3.0 		 DYN 0.8 CONF 2.4
#
#
# {'Do you live in a gated community or gentrified neighborhood ?'} {'live'}
# PART 0.2 CONF 3.0 		 DYN 0.6 CONF 3.0
#
#
# {'From my experience Hens ( Not roosters ) are very friendly with duck , Guinea pigs , kittens , cows , Rabbits , etc .'} {'are'}
# PART 0.4 CONF 2.8 		 DYN 0.0 CONF 3.0
#
#
# {'Over the past decade , Bangladesh has steadily moved into a state of lawlessness .'} {'moved'}
# PART 0.4 CONF 3.0 		 DYN 1.0 CONF 3.4
#
#
# {'The atmosphere may not be for everyone .'} {'be'}
# PART 0.4 CONF 2.6 		 DYN 0.0 CONF 2.8
#
#
# {'We are receiving invoices from Ace Federal Reporters for transcripts of the recent FERC settlement conferences .'} {'receiving'}
# PART 0.8 CONF 3.4 		 DYN 1.0 CONF 3.0
#
#
# {'We should be able to work with this .'} {'be'}
# PART 0.8 CONF 2.2 		 DYN 0.4 CONF 2.4
#
#
# {'You have patience .'} {'have'}
# PART 0.0 CONF 3.4 		 DYN 0.0 CONF 3.4
#
#
# {'Adds charm and shine to the face and skin .'} {'Adds'}
# PART 0.4 CONF 2.8 		 DYN 0.6 CONF 2.8
#
#
# {'You will also face the ire of most people there .'} {'face'}
# PART 0.6 CONF 2.6 		 DYN 0.4 CONF 2.8
#
#
# {'they r open mind for talk ?'} {'r'}
# PART 0.6 CONF 3.0 		 DYN 0.2 CONF 3.2
#
#
# {'80 - Percentage of the Iraqi workforce who are unemployed a Year after the war .'} {'are'}
# PART 0.4 CONF 2.4 		 DYN 0.2 CONF 2.4
#
#
# {'Silkies have hookless feathers .'} {'have'}
# PART 0.2 CONF 3.4 		 DYN 0.0 CONF 3.4
#
#
# {'Please do n&#39;t mention my NY trip to anyone .'} {'mention'}
# PART 0.8 CONF 3.2 		 DYN 1.0 CONF 3.0
#
#
# {'Dr. Mann killed our pet'} {'killed'}
# PART 1.0 CONF 4.0 		 DYN 1.0 CONF 4.0
#
#
# {'My experience was amazing at Providence Aesthetics and Medical Spa .'} {'was'}
# PART 0.8 CONF 3.4 		 DYN 0.0 CONF 2.8
#
#
# {'I will be looking for one or more of the following .'} {'looking'}
# PART 0.8 CONF 3.0 		 DYN 0.8 CONF 2.6
#
#
# {'Patience is the key here .'} {'is'}
# PART 0.4 CONF 2.2 		 DYN 0.0 CONF 2.8
#
#
# {'Thank you Doctor Gonzales , Doctor Stout , Eva Marie and the entire staff !'} {'Thank'}
# PART 0.6 CONF 2.4 		 DYN 0.6 CONF 2.6
#
#
# {'It is a dance for both males and females .'} {'is'}
# PART 0.8 CONF 2.6 		 DYN 0.4 CONF 2.6
#
#
# {'Make You Feel Like a Number'} {'Make'}
# PART 0.2 CONF 2.6 		 DYN 0.4 CONF 2.0
#
#
# {'Above all , never surrender to terror .'} {'surrender'}
# PART 0.6 CONF 3.0 		 DYN 0.6 CONF 2.2
#
#
# {'Service was excellent .'} {'was'}
# PART 1.0 CONF 3.4 		 DYN 0.4 CONF 3.4
#
#
# {'Instead of rescheduling they chose to waste my time instead .'} {'chose'}
# PART 0.8 CONF 3.0 		 DYN 0.6 CONF 2.8
#
#
# {'I love her . :)'} {'love'}
# PART 0.4 CONF 3.4 		 DYN 0.4 CONF 3.0
#
#
# {'This office is awesome !'} {'is'}
# PART 0.4 CONF 3.4 		 DYN 0.2 CONF 3.4
#
#
# {'On the Liberty we liked the comedian and juggling act .'} {'liked'}
# PART 1.0 CONF 3.0 		 DYN 0.2 CONF 3.2
#
#
# {'I want to take a cruise around the world .'} {'want'}
# PART 0.4 CONF 2.4 		 DYN 0.2 CONF 2.6
#
#
# {'Hancocks is one of four fabric stores in Fort Smith .'} {'is'}
# PART 0.6 CONF 3.8 		 DYN 0.0 CONF 3.8
#
#
# {'Removes wrinkles .'} {'Removes'}
# PART 0.2 CONF 3.4 		 DYN 1.0 CONF 2.2
#
#
# {'What a fantastic store , I love this place .'} {'love'}
# PART 0.6 CONF 3.0 		 DYN 0.4 CONF 3.0
#
#
# {'Tet was a huge military and political disaster for the Communists .'} {'was'}
# PART 0.8 CONF 2.6 		 DYN 0.2 CONF 3.0
#
#
# {'8 - Number of members of the US Senate and House of Representatives who have a child serving in the military .'} {'have'}
# PART 0.6 CONF 3.8 		 DYN 0.2 CONF 3.2
#
#
# {'why would you want a chihuahua ?'} {'want'}
# PART 0.6 CONF 3.4 		 DYN 0.4 CONF 2.6
#
#
# {'I also appreciate their honesty .'} {'appreciate'}
# PART 0.6 CONF 2.2 		 DYN 0.4 CONF 2.6
#
#
# {'Have fun in New Zealand !!'} {'Have'}
# PART 0.8 CONF 3.0 		 DYN 0.0 CONF 2.6
#
#
# {'I might also add a few items about international developments and the EEI physical power trading form .'} {'add'}
# PART 0.8 CONF 2.4 		 DYN 0.2 CONF 3.4
#
#
# {'Thank you again for great customer service !'} {'Thank'}
# PART 0.6 CONF 3.2 		 DYN 0.2 CONF 3.0
#
#
# {'The North Carolina Constitution likewise affirms the &quot; inalienable rights &quot; of human beings to &quot; life , liberty , the enjoyment of the fruits of their own labor , and the pursuit of happiness . &quot;'} {'affirms'}
# PART 0.8 CONF 3.0 		 DYN 0.6 CONF 3.6
#
#
# {'Because Large Fries give you FOUR PIECES !'} {'give'}
# PART 0.4 CONF 2.6 		 DYN 0.4 CONF 1.8
#
#
# {'The Shia can not live without the Sunnis , and vice versa .'} {'live'}
# PART 0.6 CONF 3.0 		 DYN 0.2 CONF 2.0
#
#
# {'We appreciated her patience , knowledge and kindness !'} {'appreciated'}
# PART 0.4 CONF 3.4 		 DYN 0.4 CONF 3.8
#
#
# {'Again , decades of this sort of behavior do not leave a person untouched .'} {'leave'}
# PART 0.2 CONF 2.8 		 DYN 0.6 CONF 3.2
#
#
# {'I have nothing but fantastic things to say .'} {'have'}
# PART 0.0 CONF 2.6 		 DYN 0.0 CONF 3.2
#
#
# {'A hiss is basically a &quot; get the f*ck away &quot; sound .'} {'is'}
# PART 0.4 CONF 3.6 		 DYN 0.0 CONF 3.4
#
#
# {'All comments , suggestions , etc. are appreciated .'} {'appreciated'}
# PART 0.2 CONF 3.2 		 DYN 0.4 CONF 2.2
#
#
# {'This is about my farrier , girls .'} {'is'}
# PART 0.8 CONF 2.6 		 DYN 0.2 CONF 3.4
#
#
# {'Cures insomnia .'} {'Cures'}
# PART 0.6 CONF 3.2 		 DYN 0.8 CONF 2.4
#
#
# {'Very few parents do this .'} {'do'}
# PART 0.6 CONF 2.8 		 DYN 0.8 CONF 2.8
#
#
# {'Take time to discover the unlimited possibilities with Agel !'} {'Take'}
# PART 0.6 CONF 3.4 		 DYN 0.4 CONF 3.4
#
#
# {'Worth every penny .'} {'Worth'}
# PART 0.6 CONF 2.6 		 DYN 0.2 CONF 3.0
#
#
# {'My dad just does n&#39;t understand ?'} {'understand'}
# PART 0.6 CONF 2.6 		 DYN 0.2 CONF 2.0
#
#
# {'King snakes sometimes stop eating , particularly during the cooler part of the year .'} {'stop'}
# PART 0.2 CONF 2.4 		 DYN 0.4 CONF 3.2
#
#
# {'I will manage client expectations accordingly .'} {'manage'}
# PART 0.6 CONF 3.4 		 DYN 0.6 CONF 3.2
#
#
# {'Here it is right here .'} {'is'}
# PART 0.6 CONF 3.4 		 DYN 0.0 CONF 3.2
#
#
# {'Lay some knowledge on them dude .'} {'Lay'}
# PART 0.0 CONF 3.0 		 DYN 0.8 CONF 3.2
#
#
# {'No Moslem preacher has ever blown himself up .'} {'blown'}
# PART 0.4 CONF 2.8 		 DYN 0.6 CONF 3.2
#
#
# {'There was not a customer to be found .'} {'was'}
# PART 0.6 CONF 2.4 		 DYN 0.0 CONF 3.4
#
#
# {'Will you pass along to the appropriate person ?'} {'pass'}
# PART 0.6 CONF 3.4 		 DYN 0.6 CONF 3.4
#
#
# {'Keep in touch !'} {'Keep'}
# PART 0.2 CONF 2.6 		 DYN 0.2 CONF 2.6
#
#
# {'In England , the cuckoo returns earlier .'} {'returns'}
# PART 0.0 CONF 3.2 		 DYN 1.0 CONF 3.6
#
#
# {'To make the war unpalatable to the American public .'} {'make'}
# PART 0.0 CONF 2.6 		 DYN 0.6 CONF 3.0
#
#
# {'I sent a customer of mine to you .'} {'sent'}
# PART 1.0 CONF 4.0 		 DYN 1.0 CONF 3.6
#
#
# {'4 ) The business is very unorganized .'} {'is'}
# PART 0.4 CONF 3.4 		 DYN 0.2 CONF 3.4
#
#
# {'I have been eating Cuban for a long time , sandwiches mainly along with other dishes ..'} {'eating'}
# PART 0.4 CONF 3.0 		 DYN 0.8 CONF 3.6
#
#
# {'According to news accounts , the company is struggling .'} {'struggling'}
# PART 0.8 CONF 3.0 		 DYN 0.8 CONF 3.2
#
#
# {'Yet , there is warmth and a familiarity with the vastness .'} {'is'}
# PART 0.2 CONF 3.2 		 DYN 0.0 CONF 3.6
#
#
# {'They have fabulous French toast too .'} {'have'}
# PART 0.4 CONF 2.4 		 DYN 0.0 CONF 2.8
#
#
# {'How can i get Weed in Auckland ?'} {'get'}
# PART 0.6 CONF 2.8 		 DYN 0.8 CONF 3.0
#
#
# {'The United States truly no longer has time for faulty analysis or politically - based preconceptions .'} {'has'}
# PART 0.4 CONF 3.0 		 DYN 0.2 CONF 3.2
#
#
# {'1562 St Teresa , a Spanish reformer , includes chess in her writings .'} {'includes'}
# PART 0.6 CONF 3.0 		 DYN 0.6 CONF 3.2
#
#
# {'I have many fond memories of my college evenings there long ago .'} {'have'}
# PART 0.6 CONF 2.8 		 DYN 0.2 CONF 2.8
#
#
# {'he will feel much safer in that one room , than in a huge unknown house .'} {'feel'}
# PART 0.6 CONF 2.8 		 DYN 0.4 CONF 3.0
